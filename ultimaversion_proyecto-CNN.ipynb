# %% [markdown]
# <center><h1>Inteligencia Artificial</header1></center>

# %% [markdown]
# Presentado por: Enriquez Selena y Johana Salazar  <br>
# Fecha: DD/MM/2022

# %% [markdown]
# # Importación de librerias necesarias

# %%
#Para esta actividad se importarán las siguientes librerías:
import cv2
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import shutil
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from  PIL  import Image
from rembg import remove
from sklearn.preprocessing import MinMaxScaler
import h5py
from time import sleep
from sklearn.model_selection import train_test_split
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten,\
 Conv2D, MaxPooling2D,BatchNormalization,LayerNormalization

# %% [markdown]
# ## Cargar el Dataset

# %%
#Procedemos a cargar las imagenes para lo cual especificamos el nombre del archivo
images_path = "./PROYECTOIAf"
#images_path = "/Users/johan/Downloads/principal/proyectoIA"
class_names = os.listdir(images_path)
class_names.sort()
print(class_names)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MasacheFernando', 'MelanyLopez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMaria', 'PauteKevin', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %% [markdown]
# ## Descripción de la fuente

# %% [markdown]
#     Las imagenes se encuantran en una carpeta denominada "proyectoIA",se procede a cargar  imagenes de caracteristicas distintas. Dichas imagenes sera utilizados entrenar el modelo que permita la autenticacion del ususario por medio de un aplicativo.En el cual las imagenes seran entrenadas para la dicha autenticacion.

# %% [markdown]
# ## Explique el problema a resolver.

# %% [markdown]
# En el siguiente trabajo usamos imagenes que van a ser entrenadas por medio de un algoritmo supervisado. Para lograr esto se crea etiquetas con valores, esa información entrada y salida esperada. La red al entrenar ajustará los pesos de las Neuronas. La red a utilizar es Convolutional Neural Network, por ello necesitamos la libreria keras y tensorflow.

# %% [markdown]
# ## Caracterización del Dataset
#
# Realice una descripción de los datos con:
#
# >- Número de instancias en total.
# >- Número de atributos de entrada, su significado y tipo.
# >- Estadísticas de la variable objetivo.
# >- Estadísticas los atributos en relación con la variable objetivo.

# %% [markdown]
# Vamos a trabajar con un total de 3 imagenes por cada estudiante en este caso son 5 personas, dichas imagenes esen en formato png por lo tanto esoecificamos en la ruta. El tamaño que se maneja en las imagenes es de carnet americano. Aunque no tiene todas las mismas medidas con el preproceso se resuelve el problema.

# %%
#Especificamos la carpeta donde se va a proceder a realizar el aumento
for class_name in class_names:
    cur_path = images_path + "/" + class_name
    elements = os.listdir(cur_path)
    
    for element in elements:
        print("Copying Image - {} in PROYECTOIA-AUMENTADO/{}".format(element, class_name))
        src = os.path.join(images_path + "/" + class_name, element) # origen
        dst = os.path.join("./PROYECTOIA-AUMENTADO/" + class_name, element) 
        shutil.copy(src, dst)
# Out:
# Copying Image - L00376418_1.jpg in PROYECTOIA-AUMENTADO/Ariel Chabla
# Copying Image - L00376418_2.jpg in PROYECTOIA-AUMENTADO/Ariel Chabla
# Copying Image - L00376418_3.jpg in PROYECTOIA-AUMENTADO/Ariel Chabla
# Copying Image - L00376418_4.jpg in PROYECTOIA-AUMENTADO/Ariel Chabla
# Copying Image - L00376418_5.jpg in PROYECTOIA-AUMENTADO/Ariel Chabla
# Copying Image - L00376418_6.jpg in PROYECTOIA-AUMENTADO/Ariel Chabla
# Copying Image - L00376418_7.jpg in PROYECTOIA-AUMENTADO/Ariel Chabla
# Copying Image - L00376418_8.jpg in PROYECTOIA-AUMENTADO/Ariel Chabla
# Copying Image - L00385770_1.jpg in PROYECTOIA-AUMENTADO/ArroboMercy
# Copying Image - L00385770_2.jpg in PROYECTOIA-AUMENTADO/ArroboMercy
# Copying Image - L00385770_3.jpg in PROYECTOIA-AUMENTADO/ArroboMercy
# Copying Image - L00385770_4.jpg in PROYECTOIA-AUMENTADO/ArroboMercy
# Copying Image - L00385770_5.jpg in PROYECTOIA-AUMENTADO/ArroboMercy
# Copying Image - L00385770_6.jpg in PROYECTOIA-AUMENTADO/ArroboMercy
# Copying Image - L00385770_7.jpg in PROYECTOIA-AUMENTADO/ArroboMercy
# Copying Image - L00385770_8.jpg in PROYECTOIA-AUMENTADO/ArroboMercy
# Copying Image - L00392978_1.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_10.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_11.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_12.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_13.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_14.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_2.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_3.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_4.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_5.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_6.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_7.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_8.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00392978_9.jpg in PROYECTOIA-AUMENTADO/BarraganSteven
# Copying Image - L00376416_1.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L00376416_2.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L00376416_3.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L00376416_4.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L00376416_5.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L00376416_6.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L00376416_7.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L00376416_8.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L00376416_9.jpg in PROYECTOIA-AUMENTADO/CevallosJoan
# Copying Image - L000376481_1.jpg in PROYECTOIA-AUMENTADO/EnriquezSelena
# Copying Image - L000376481_2.jpg in PROYECTOIA-AUMENTADO/EnriquezSelena
# Copying Image - L000376481_3.jpg in PROYECTOIA-AUMENTADO/EnriquezSelena
# Copying Image - L000376481_4.jpg in PROYECTOIA-AUMENTADO/EnriquezSelena
# Copying Image - L000376481_5.jpg in PROYECTOIA-AUMENTADO/EnriquezSelena
# Copying Image - L00392991_1.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_10.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_2.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_3.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_4.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_5.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_6.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_7.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_8.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00392991_9.jpeg in PROYECTOIA-AUMENTADO/GenesisHeredia
# Copying Image - L00393010_1.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_10.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_2.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_3.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_4.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_5.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_6.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_7.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_8.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00393010_9.jpg in PROYECTOIA-AUMENTADO/GoyesAnthony
# Copying Image - L00392993_10.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_11.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_12.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_13.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_4.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_5.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_6.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_7.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_8.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_9.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_Centro.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_LD.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00392993_LI.jpg in PROYECTOIA-AUMENTADO/Jhon Zambrano
# Copying Image - L00080128_2 Derecho.png in PROYECTOIA-AUMENTADO/Jordan Espinosa
# Copying Image - L00080128_3 Izquierda.png in PROYECTOIA-AUMENTADO/Jordan Espinosa
# Copying Image - L00080128_4.jpg in PROYECTOIA-AUMENTADO/Jordan Espinosa
# Copying Image - L00080128_5.jpg in PROYECTOIA-AUMENTADO/Jordan Espinosa
# Copying Image - L00080128_6.jpg in PROYECTOIA-AUMENTADO/Jordan Espinosa
# Copying Image - L00080128_7.jpg in PROYECTOIA-AUMENTADO/Jordan Espinosa
# Copying Image - L00080128_8.jpg in PROYECTOIA-AUMENTADO/Jordan Espinosa
# Copying Image - L00379412_1.jpeg in PROYECTOIA-AUMENTADO/Jorge Borrero
# Copying Image - L00379412_2.jpeg in PROYECTOIA-AUMENTADO/Jorge Borrero
# Copying Image - L00379412_3.jpeg in PROYECTOIA-AUMENTADO/Jorge Borrero
# Copying Image - L00380361_1.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_10.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_2.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_3.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_4.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_5.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_6.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_7.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_8.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00380361_9.jpg in PROYECTOIA-AUMENTADO/JoseRuiz
# Copying Image - L00393009_1.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_10.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_2.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_3.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_4.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_5.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_6.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_7.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_8.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - L00393009_9.jpeg in PROYECTOIA-AUMENTADO/LucioCarlos
# Copying Image - 20220803_1.jpg in PROYECTOIA-AUMENTADO/MasacheFernando
# Copying Image - 20220803_2.jpg in PROYECTOIA-AUMENTADO/MasacheFernando
# Copying Image - 20220803_3.jpg in PROYECTOIA-AUMENTADO/MasacheFernando
# Copying Image - 20220817_3.jpg in PROYECTOIA-AUMENTADO/MasacheFernando
# Copying Image - 20220817_4.jpg in PROYECTOIA-AUMENTADO/MasacheFernando
# Copying Image - 20220817_5.jpg in PROYECTOIA-AUMENTADO/MasacheFernando
# Copying Image - 20220817_6.jpg in PROYECTOIA-AUMENTADO/MasacheFernando
# Copying Image - L00392999_1.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_10.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_11.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_2.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_3.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_4.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_5.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_6.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_7.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_8.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00392999_9.jpg in PROYECTOIA-AUMENTADO/MelanyLopez
# Copying Image - L00073392_1.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00073392_2.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00073392_3.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00073392_4.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00073392_5.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00073392_6.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00073392_7.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00073392_8.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00073392_9.jpg in PROYECTOIA-AUMENTADO/MosqueraLucy
# Copying Image - L00380424_4.jpg in PROYECTOIA-AUMENTADO/Nataly Acosta
# Copying Image - L00380424_5.jpg in PROYECTOIA-AUMENTADO/Nataly Acosta
# Copying Image - L00380424_6.jpg in PROYECTOIA-AUMENTADO/Nataly Acosta
# Copying Image - L00380424_7.jpg in PROYECTOIA-AUMENTADO/Nataly Acosta
# Copying Image - L00380424_8.jpg in PROYECTOIA-AUMENTADO/Nataly Acosta
# Copying Image - L00393001_10.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_11.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_12.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_13.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_4.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_5.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_6.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_7.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_8.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00393001_9.jpg in PROYECTOIA-AUMENTADO/OlallaLuis
# Copying Image - L00392984_1.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_10.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_2.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_3.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_4.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_5.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_6.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_7.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_8.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00392984_9.jpg in PROYECTOIA-AUMENTADO/ParragaMaria
# Copying Image - L00080134_10.jpg in PROYECTOIA-AUMENTADO/PauteKevin
# Copying Image - L00080134_4.jpg in PROYECTOIA-AUMENTADO/PauteKevin
# Copying Image - L00080134_5.jpg in PROYECTOIA-AUMENTADO/PauteKevin
# Copying Image - L00080134_6.jpg in PROYECTOIA-AUMENTADO/PauteKevin
# Copying Image - L00080134_7.jpg in PROYECTOIA-AUMENTADO/PauteKevin
# Copying Image - L00080134_8.jpg in PROYECTOIA-AUMENTADO/PauteKevin
# Copying Image - L00080134_9.jpg in PROYECTOIA-AUMENTADO/PauteKevin
# Copying Image - L00376689_1.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_10.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_11.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_2.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_3.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_4.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_5.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_6.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_7.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_8.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00376689_9.jpg in PROYECTOIA-AUMENTADO/RivasSelena
# Copying Image - L00380416_1.png in PROYECTOIA-AUMENTADO/SalazarJohana
# Copying Image - L00380416_2.png in PROYECTOIA-AUMENTADO/SalazarJohana
# Copying Image - L00380416_3.png in PROYECTOIA-AUMENTADO/SalazarJohana
# Copying Image - L00380416_4.png in PROYECTOIA-AUMENTADO/SalazarJohana
# Copying Image - L00380416_5.png in PROYECTOIA-AUMENTADO/SalazarJohana
# Copying Image - L00392980_1.jpg in PROYECTOIA-AUMENTADO/Solano Wilmer
# Copying Image - L00392980_2.jpg in PROYECTOIA-AUMENTADO/Solano Wilmer
# Copying Image - L00392980_3.jpg in PROYECTOIA-AUMENTADO/Solano Wilmer
# Copying Image - L00392980_4.jpg in PROYECTOIA-AUMENTADO/Solano Wilmer
# Copying Image - L00392980_5.jpg in PROYECTOIA-AUMENTADO/Solano Wilmer
# Copying Image - L00080131_1.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00080131_2.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00080131_3.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00080131_4.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00080131_5.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00080131_6.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00080131_7.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00080131_8.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00080131_9.jpg in PROYECTOIA-AUMENTADO/SolorzanoBryan
# Copying Image - L00393007_1.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_10.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_2.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_3.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_4.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_5.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_6.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_7.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_8.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja
# Copying Image - L00393007_9.jpeg in PROYECTOIA-AUMENTADO/VinicioBorja

# %%
"""Se define la rotacion, ancho, desplazamiento, el zoom y el rango de escala"""

datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
"""Creando imagenes aumentadas para la carpeta de Ariel """
#ruta hacia la carpeta
os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\Ariel Chabla")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Ariel Chabla', 
            save_format='jpg'):
        i += 1
        #Especificamos el numero de imagenes a aumentar en este caso necesitamos 9 imagenes de cada lado.
        #Para el aumento en cada carpeta serian 30 imagenes.
        if i == 9:      
            break

# %%
"""Creando imagnes aumentadas para la carpeta de ArroboMercy"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\ArroboMercy")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'ArroboMercy', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpeta de Barragan"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\BarraganSteven")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'BarraganSteven', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\CevallosJoan")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'CevallosJoan', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\GenesisHeredia")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'GenesisHeredia', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\EnriquezSelena")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'EnriquezSelena', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\GoyesAnthony")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'GoyesAnthony', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\Jhon Zambrano")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Jhon Zambrano', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\Jordan Espinosa")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Jordan Espinosa', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\Jorge Borrero")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Jorge Borrero', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\JoseRuiz")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'JoseRuiz', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\LucioCarlos")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'LucioCarlos', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\MasacheFernando")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'MasacheFernando', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\MelanyLopez")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'MelanyLopez', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\MosqueraLucy")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'MosqueraLucy', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\Nataly Acosta")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Nataly Acosta', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\OlallaLuis")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'OlallaLuis', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\ParragaMaria")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'ParragaMaria', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\PauteKevin")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'PauteKevin', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\RivasSelena")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'RivasSelena', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\SalazarJohana")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'SalazarJohana', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\Solano Wilmer")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Solano Wilmer', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\SolorzanoBryan")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'SolorzanoBryan', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %%
"""Creando imagnes aumentadas para la carpetA"""

os.chdir(r"\Users\johan\Downloads\PROYECTOIA-AUMENTADO\VinicioBorja")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'VinicioBorja', 
            save_format='jpg'):
        i += 1
        if i == 9:     ## creates 10 image form 1 image 
            break

# %% [markdown]
# ## NLM Filtro para eliminar el ruido de la imagen

# %%
"""Procedemos a la eliminacion del ruido de las imagenes en cada una de las carpetas de acada persona """


#os.chdir(r"/Users/johan/Downloads/")
os.chdir(r"/Users/johan/Downloads/")
images_path = "./PROYECTOIA-AUMENTADO"
class_names = os.listdir(images_path)
class_names.sort()
print(class_names)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MasacheFernando', 'MelanyLopez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMaria', 'PauteKevin', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %%
"""De las imagenes aumentadas obtenidas del codigo anterior se procede a procesar cada una con el fin de eliminar el ruido
Especificamos la carpeta del proceso y tambienla carpeta donde se guardan las imagenes sin ruido"""

for class_name in class_names:
    cur_path = images_path + "/" + class_name
    cur_label = class_name
    i = 1

    for file in glob.glob(cur_path + "/*"):
        print("Processing Image - {} in {}".format(i, cur_label))
        # read the images path
        image = cv2.imread(file)
        # denoising images
        dst = cv2.fastNlMeansDenoisingColored(image,None,10,10,7,21)
        b,g,r = cv2.split(dst)
        rgb_dst = cv2.merge([r,g,b])
        # save images
        save_path = './DESING/'+ cur_label
        cv2.imwrite(os.path.join(save_path , cur_label + '_' + str(i) + '.jpg'),
                    cv2.cvtColor(rgb_dst,cv2.COLOR_RGB2BGR))
        

        # show loop update
        i += 1
# Out:
# Processing Image - 1 in Ariel Chabla
# Processing Image - 2 in Ariel Chabla
# Processing Image - 3 in Ariel Chabla
# Processing Image - 4 in Ariel Chabla
# Processing Image - 5 in Ariel Chabla
# Processing Image - 6 in Ariel Chabla
# Processing Image - 7 in Ariel Chabla
# Processing Image - 8 in Ariel Chabla
# Processing Image - 9 in Ariel Chabla
# Processing Image - 10 in Ariel Chabla
# Processing Image - 11 in Ariel Chabla
# Processing Image - 12 in Ariel Chabla
# Processing Image - 13 in Ariel Chabla
# Processing Image - 14 in Ariel Chabla
# Processing Image - 15 in Ariel Chabla
# Processing Image - 16 in Ariel Chabla
# Processing Image - 17 in Ariel Chabla
# Processing Image - 18 in Ariel Chabla
# Processing Image - 19 in Ariel Chabla
# Processing Image - 20 in Ariel Chabla
# Processing Image - 21 in Ariel Chabla
# Processing Image - 22 in Ariel Chabla
# Processing Image - 23 in Ariel Chabla
# Processing Image - 24 in Ariel Chabla
# Processing Image - 25 in Ariel Chabla
# Processing Image - 26 in Ariel Chabla
# Processing Image - 27 in Ariel Chabla
# Processing Image - 28 in Ariel Chabla
# Processing Image - 29 in Ariel Chabla
# Processing Image - 30 in Ariel Chabla
# Processing Image - 31 in Ariel Chabla
# Processing Image - 32 in Ariel Chabla
# Processing Image - 33 in Ariel Chabla
# Processing Image - 34 in Ariel Chabla
# Processing Image - 35 in Ariel Chabla
# Processing Image - 36 in Ariel Chabla
# Processing Image - 37 in Ariel Chabla
# Processing Image - 38 in Ariel Chabla
# Processing Image - 39 in Ariel Chabla
# Processing Image - 40 in Ariel Chabla
# Processing Image - 41 in Ariel Chabla
# Processing Image - 42 in Ariel Chabla
# Processing Image - 43 in Ariel Chabla
# Processing Image - 44 in Ariel Chabla
# Processing Image - 45 in Ariel Chabla
# Processing Image - 46 in Ariel Chabla
# Processing Image - 47 in Ariel Chabla
# Processing Image - 48 in Ariel Chabla
# Processing Image - 49 in Ariel Chabla
# Processing Image - 50 in Ariel Chabla
# Processing Image - 51 in Ariel Chabla
# Processing Image - 52 in Ariel Chabla
# Processing Image - 53 in Ariel Chabla
# Processing Image - 54 in Ariel Chabla
# Processing Image - 55 in Ariel Chabla
# Processing Image - 56 in Ariel Chabla
# Processing Image - 57 in Ariel Chabla
# Processing Image - 58 in Ariel Chabla
# Processing Image - 59 in Ariel Chabla
# Processing Image - 60 in Ariel Chabla
# Processing Image - 61 in Ariel Chabla
# Processing Image - 62 in Ariel Chabla
# Processing Image - 63 in Ariel Chabla
# Processing Image - 64 in Ariel Chabla
# Processing Image - 65 in Ariel Chabla
# Processing Image - 66 in Ariel Chabla
# Processing Image - 67 in Ariel Chabla
# Processing Image - 68 in Ariel Chabla
# Processing Image - 69 in Ariel Chabla
# Processing Image - 70 in Ariel Chabla
# Processing Image - 71 in Ariel Chabla
# Processing Image - 72 in Ariel Chabla
# Processing Image - 73 in Ariel Chabla
# Processing Image - 74 in Ariel Chabla
# Processing Image - 75 in Ariel Chabla
# Processing Image - 76 in Ariel Chabla
# Processing Image - 77 in Ariel Chabla
# Processing Image - 78 in Ariel Chabla
# Processing Image - 79 in Ariel Chabla
# Processing Image - 80 in Ariel Chabla
# Processing Image - 1 in ArroboMercy
# Processing Image - 2 in ArroboMercy
# Processing Image - 3 in ArroboMercy
# Processing Image - 4 in ArroboMercy
# Processing Image - 5 in ArroboMercy
# Processing Image - 6 in ArroboMercy
# Processing Image - 7 in ArroboMercy
# Processing Image - 8 in ArroboMercy
# Processing Image - 9 in ArroboMercy
# Processing Image - 10 in ArroboMercy
# Processing Image - 11 in ArroboMercy
# Processing Image - 12 in ArroboMercy
# Processing Image - 13 in ArroboMercy
# Processing Image - 14 in ArroboMercy
# Processing Image - 15 in ArroboMercy
# Processing Image - 16 in ArroboMercy
# Processing Image - 17 in ArroboMercy
# Processing Image - 18 in ArroboMercy
# Processing Image - 19 in ArroboMercy
# Processing Image - 20 in ArroboMercy
# Processing Image - 21 in ArroboMercy
# Processing Image - 22 in ArroboMercy
# Processing Image - 23 in ArroboMercy
# Processing Image - 24 in ArroboMercy
# Processing Image - 25 in ArroboMercy
# Processing Image - 26 in ArroboMercy
# Processing Image - 27 in ArroboMercy
# Processing Image - 28 in ArroboMercy
# Processing Image - 29 in ArroboMercy
# Processing Image - 30 in ArroboMercy
# Processing Image - 31 in ArroboMercy
# Processing Image - 32 in ArroboMercy
# Processing Image - 33 in ArroboMercy
# Processing Image - 34 in ArroboMercy
# Processing Image - 35 in ArroboMercy
# Processing Image - 36 in ArroboMercy
# Processing Image - 37 in ArroboMercy
# Processing Image - 38 in ArroboMercy
# Processing Image - 39 in ArroboMercy
# Processing Image - 40 in ArroboMercy
# Processing Image - 41 in ArroboMercy
# Processing Image - 42 in ArroboMercy
# Processing Image - 43 in ArroboMercy
# Processing Image - 44 in ArroboMercy
# Processing Image - 45 in ArroboMercy
# Processing Image - 46 in ArroboMercy
# Processing Image - 47 in ArroboMercy
# Processing Image - 48 in ArroboMercy
# Processing Image - 49 in ArroboMercy
# Processing Image - 50 in ArroboMercy
# Processing Image - 51 in ArroboMercy
# Processing Image - 52 in ArroboMercy
# Processing Image - 53 in ArroboMercy
# Processing Image - 54 in ArroboMercy
# Processing Image - 55 in ArroboMercy
# Processing Image - 56 in ArroboMercy
# Processing Image - 57 in ArroboMercy
# Processing Image - 58 in ArroboMercy
# Processing Image - 59 in ArroboMercy
# Processing Image - 60 in ArroboMercy
# Processing Image - 61 in ArroboMercy
# Processing Image - 62 in ArroboMercy
# Processing Image - 63 in ArroboMercy
# Processing Image - 64 in ArroboMercy
# Processing Image - 65 in ArroboMercy
# Processing Image - 66 in ArroboMercy
# Processing Image - 67 in ArroboMercy
# Processing Image - 68 in ArroboMercy
# Processing Image - 69 in ArroboMercy
# Processing Image - 70 in ArroboMercy
# Processing Image - 71 in ArroboMercy
# Processing Image - 72 in ArroboMercy
# Processing Image - 73 in ArroboMercy
# Processing Image - 74 in ArroboMercy
# Processing Image - 75 in ArroboMercy
# Processing Image - 76 in ArroboMercy
# Processing Image - 77 in ArroboMercy
# Processing Image - 78 in ArroboMercy
# Processing Image - 79 in ArroboMercy
# Processing Image - 1 in BarraganSteven
# Processing Image - 2 in BarraganSteven
# Processing Image - 3 in BarraganSteven
# Processing Image - 4 in BarraganSteven
# Processing Image - 5 in BarraganSteven
# Processing Image - 6 in BarraganSteven
# Processing Image - 7 in BarraganSteven
# Processing Image - 8 in BarraganSteven
# Processing Image - 9 in BarraganSteven
# Processing Image - 10 in BarraganSteven
# Processing Image - 11 in BarraganSteven
# Processing Image - 12 in BarraganSteven
# Processing Image - 13 in BarraganSteven
# Processing Image - 14 in BarraganSteven
# Processing Image - 15 in BarraganSteven
# Processing Image - 16 in BarraganSteven
# Processing Image - 17 in BarraganSteven
# Processing Image - 18 in BarraganSteven
# Processing Image - 19 in BarraganSteven
# Processing Image - 20 in BarraganSteven
# Processing Image - 21 in BarraganSteven
# Processing Image - 22 in BarraganSteven
# Processing Image - 23 in BarraganSteven
# Processing Image - 24 in BarraganSteven
# Processing Image - 25 in BarraganSteven
# Processing Image - 26 in BarraganSteven
# Processing Image - 27 in BarraganSteven
# Processing Image - 28 in BarraganSteven
# Processing Image - 29 in BarraganSteven
# Processing Image - 30 in BarraganSteven
# Processing Image - 31 in BarraganSteven
# Processing Image - 32 in BarraganSteven
# Processing Image - 33 in BarraganSteven
# Processing Image - 34 in BarraganSteven
# Processing Image - 35 in BarraganSteven
# Processing Image - 36 in BarraganSteven
# Processing Image - 37 in BarraganSteven
# Processing Image - 38 in BarraganSteven
# Processing Image - 39 in BarraganSteven
# Processing Image - 40 in BarraganSteven
# Processing Image - 41 in BarraganSteven
# Processing Image - 42 in BarraganSteven
# Processing Image - 43 in BarraganSteven
# Processing Image - 44 in BarraganSteven
# Processing Image - 45 in BarraganSteven
# Processing Image - 46 in BarraganSteven
# Processing Image - 47 in BarraganSteven
# Processing Image - 48 in BarraganSteven
# Processing Image - 49 in BarraganSteven
# Processing Image - 50 in BarraganSteven
# Processing Image - 51 in BarraganSteven
# Processing Image - 52 in BarraganSteven
# Processing Image - 53 in BarraganSteven
# Processing Image - 54 in BarraganSteven
# Processing Image - 55 in BarraganSteven
# Processing Image - 56 in BarraganSteven
# Processing Image - 57 in BarraganSteven
# Processing Image - 58 in BarraganSteven
# Processing Image - 59 in BarraganSteven
# Processing Image - 60 in BarraganSteven
# Processing Image - 61 in BarraganSteven
# Processing Image - 62 in BarraganSteven
# Processing Image - 63 in BarraganSteven
# Processing Image - 64 in BarraganSteven
# Processing Image - 65 in BarraganSteven
# Processing Image - 66 in BarraganSteven
# Processing Image - 67 in BarraganSteven
# Processing Image - 68 in BarraganSteven
# Processing Image - 69 in BarraganSteven
# Processing Image - 70 in BarraganSteven
# Processing Image - 71 in BarraganSteven
# Processing Image - 72 in BarraganSteven
# Processing Image - 73 in BarraganSteven
# Processing Image - 74 in BarraganSteven
# Processing Image - 75 in BarraganSteven
# Processing Image - 76 in BarraganSteven
# Processing Image - 77 in BarraganSteven
# Processing Image - 78 in BarraganSteven
# Processing Image - 79 in BarraganSteven
# Processing Image - 80 in BarraganSteven
# Processing Image - 81 in BarraganSteven
# Processing Image - 82 in BarraganSteven
# Processing Image - 83 in BarraganSteven
# Processing Image - 84 in BarraganSteven
# Processing Image - 85 in BarraganSteven
# Processing Image - 86 in BarraganSteven
# Processing Image - 87 in BarraganSteven
# Processing Image - 88 in BarraganSteven
# Processing Image - 89 in BarraganSteven
# Processing Image - 90 in BarraganSteven
# Processing Image - 91 in BarraganSteven
# Processing Image - 92 in BarraganSteven
# Processing Image - 93 in BarraganSteven
# Processing Image - 94 in BarraganSteven
# Processing Image - 95 in BarraganSteven
# Processing Image - 96 in BarraganSteven
# Processing Image - 97 in BarraganSteven
# Processing Image - 98 in BarraganSteven
# Processing Image - 99 in BarraganSteven
# Processing Image - 100 in BarraganSteven
# Processing Image - 101 in BarraganSteven
# Processing Image - 102 in BarraganSteven
# Processing Image - 103 in BarraganSteven
# Processing Image - 104 in BarraganSteven
# Processing Image - 105 in BarraganSteven
# Processing Image - 106 in BarraganSteven
# Processing Image - 107 in BarraganSteven
# Processing Image - 108 in BarraganSteven
# Processing Image - 109 in BarraganSteven
# Processing Image - 110 in BarraganSteven
# Processing Image - 111 in BarraganSteven
# Processing Image - 112 in BarraganSteven
# Processing Image - 113 in BarraganSteven
# Processing Image - 114 in BarraganSteven
# Processing Image - 115 in BarraganSteven
# Processing Image - 116 in BarraganSteven
# Processing Image - 117 in BarraganSteven
# Processing Image - 118 in BarraganSteven
# Processing Image - 119 in BarraganSteven
# Processing Image - 120 in BarraganSteven
# Processing Image - 121 in BarraganSteven
# Processing Image - 122 in BarraganSteven
# Processing Image - 123 in BarraganSteven
# Processing Image - 124 in BarraganSteven
# Processing Image - 125 in BarraganSteven
# Processing Image - 126 in BarraganSteven
# Processing Image - 127 in BarraganSteven
# Processing Image - 128 in BarraganSteven
# Processing Image - 129 in BarraganSteven
# Processing Image - 130 in BarraganSteven
# Processing Image - 131 in BarraganSteven
# Processing Image - 132 in BarraganSteven
# Processing Image - 133 in BarraganSteven
# Processing Image - 134 in BarraganSteven
# Processing Image - 135 in BarraganSteven
# Processing Image - 136 in BarraganSteven
# Processing Image - 137 in BarraganSteven
# Processing Image - 138 in BarraganSteven
# Processing Image - 139 in BarraganSteven
# Processing Image - 140 in BarraganSteven
# Processing Image - 1 in CevallosJoan
# Processing Image - 2 in CevallosJoan
# Processing Image - 3 in CevallosJoan
# Processing Image - 4 in CevallosJoan
# Processing Image - 5 in CevallosJoan
# Processing Image - 6 in CevallosJoan
# Processing Image - 7 in CevallosJoan
# Processing Image - 8 in CevallosJoan
# Processing Image - 9 in CevallosJoan
# Processing Image - 1 in EnriquezSelena
# Processing Image - 2 in EnriquezSelena
# Processing Image - 3 in EnriquezSelena
# Processing Image - 4 in EnriquezSelena
# Processing Image - 5 in EnriquezSelena
# Processing Image - 6 in EnriquezSelena
# Processing Image - 7 in EnriquezSelena
# Processing Image - 8 in EnriquezSelena
# Processing Image - 9 in EnriquezSelena
# Processing Image - 10 in EnriquezSelena
# Processing Image - 11 in EnriquezSelena
# Processing Image - 12 in EnriquezSelena
# Processing Image - 13 in EnriquezSelena
# Processing Image - 14 in EnriquezSelena
# Processing Image - 15 in EnriquezSelena
# Processing Image - 16 in EnriquezSelena
# Processing Image - 17 in EnriquezSelena
# Processing Image - 18 in EnriquezSelena
# Processing Image - 19 in EnriquezSelena
# Processing Image - 20 in EnriquezSelena
# Processing Image - 21 in EnriquezSelena
# Processing Image - 22 in EnriquezSelena
# Processing Image - 23 in EnriquezSelena
# Processing Image - 24 in EnriquezSelena
# Processing Image - 25 in EnriquezSelena
# Processing Image - 26 in EnriquezSelena
# Processing Image - 27 in EnriquezSelena
# Processing Image - 28 in EnriquezSelena
# Processing Image - 29 in EnriquezSelena
# Processing Image - 30 in EnriquezSelena
# Processing Image - 31 in EnriquezSelena
# Processing Image - 32 in EnriquezSelena
# Processing Image - 33 in EnriquezSelena
# Processing Image - 34 in EnriquezSelena
# Processing Image - 35 in EnriquezSelena
# Processing Image - 36 in EnriquezSelena
# Processing Image - 37 in EnriquezSelena
# Processing Image - 38 in EnriquezSelena
# Processing Image - 39 in EnriquezSelena
# Processing Image - 40 in EnriquezSelena
# Processing Image - 41 in EnriquezSelena
# Processing Image - 42 in EnriquezSelena
# Processing Image - 43 in EnriquezSelena
# Processing Image - 44 in EnriquezSelena
# Processing Image - 45 in EnriquezSelena
# Processing Image - 46 in EnriquezSelena
# Processing Image - 47 in EnriquezSelena
# Processing Image - 48 in EnriquezSelena
# Processing Image - 49 in EnriquezSelena
# Processing Image - 50 in EnriquezSelena
# Processing Image - 1 in GenesisHeredia
# Processing Image - 2 in GenesisHeredia
# Processing Image - 3 in GenesisHeredia
# Processing Image - 4 in GenesisHeredia
# Processing Image - 5 in GenesisHeredia
# Processing Image - 6 in GenesisHeredia
# Processing Image - 7 in GenesisHeredia
# Processing Image - 8 in GenesisHeredia
# Processing Image - 9 in GenesisHeredia
# Processing Image - 10 in GenesisHeredia
# Processing Image - 11 in GenesisHeredia
# Processing Image - 12 in GenesisHeredia
# Processing Image - 13 in GenesisHeredia
# Processing Image - 14 in GenesisHeredia
# Processing Image - 15 in GenesisHeredia
# Processing Image - 16 in GenesisHeredia
# Processing Image - 17 in GenesisHeredia
# Processing Image - 18 in GenesisHeredia
# Processing Image - 19 in GenesisHeredia
# Processing Image - 20 in GenesisHeredia
# Processing Image - 21 in GenesisHeredia
# Processing Image - 22 in GenesisHeredia
# Processing Image - 23 in GenesisHeredia
# Processing Image - 24 in GenesisHeredia
# Processing Image - 25 in GenesisHeredia
# Processing Image - 26 in GenesisHeredia
# Processing Image - 27 in GenesisHeredia
# Processing Image - 28 in GenesisHeredia
# Processing Image - 29 in GenesisHeredia
# Processing Image - 30 in GenesisHeredia
# Processing Image - 31 in GenesisHeredia
# Processing Image - 32 in GenesisHeredia
# Processing Image - 33 in GenesisHeredia
# Processing Image - 34 in GenesisHeredia
# Processing Image - 35 in GenesisHeredia
# Processing Image - 36 in GenesisHeredia
# Processing Image - 37 in GenesisHeredia
# Processing Image - 38 in GenesisHeredia
# Processing Image - 39 in GenesisHeredia
# Processing Image - 40 in GenesisHeredia
# Processing Image - 41 in GenesisHeredia
# Processing Image - 42 in GenesisHeredia
# Processing Image - 43 in GenesisHeredia
# Processing Image - 44 in GenesisHeredia
# Processing Image - 45 in GenesisHeredia
# Processing Image - 46 in GenesisHeredia
# Processing Image - 47 in GenesisHeredia
# Processing Image - 48 in GenesisHeredia
# Processing Image - 49 in GenesisHeredia
# Processing Image - 50 in GenesisHeredia
# Processing Image - 51 in GenesisHeredia
# Processing Image - 52 in GenesisHeredia
# Processing Image - 53 in GenesisHeredia
# Processing Image - 54 in GenesisHeredia
# Processing Image - 55 in GenesisHeredia
# Processing Image - 56 in GenesisHeredia
# Processing Image - 57 in GenesisHeredia
# Processing Image - 58 in GenesisHeredia
# Processing Image - 59 in GenesisHeredia
# Processing Image - 60 in GenesisHeredia
# Processing Image - 61 in GenesisHeredia
# Processing Image - 62 in GenesisHeredia
# Processing Image - 63 in GenesisHeredia
# Processing Image - 64 in GenesisHeredia
# Processing Image - 65 in GenesisHeredia
# Processing Image - 66 in GenesisHeredia
# Processing Image - 67 in GenesisHeredia
# Processing Image - 68 in GenesisHeredia
# Processing Image - 69 in GenesisHeredia
# Processing Image - 70 in GenesisHeredia
# Processing Image - 71 in GenesisHeredia
# Processing Image - 72 in GenesisHeredia
# Processing Image - 73 in GenesisHeredia
# Processing Image - 74 in GenesisHeredia
# Processing Image - 75 in GenesisHeredia
# Processing Image - 76 in GenesisHeredia
# Processing Image - 77 in GenesisHeredia
# Processing Image - 78 in GenesisHeredia
# Processing Image - 79 in GenesisHeredia
# Processing Image - 80 in GenesisHeredia
# Processing Image - 81 in GenesisHeredia
# Processing Image - 82 in GenesisHeredia
# Processing Image - 83 in GenesisHeredia
# Processing Image - 84 in GenesisHeredia
# Processing Image - 85 in GenesisHeredia
# Processing Image - 86 in GenesisHeredia
# Processing Image - 87 in GenesisHeredia
# Processing Image - 88 in GenesisHeredia
# Processing Image - 89 in GenesisHeredia
# Processing Image - 90 in GenesisHeredia
# Processing Image - 91 in GenesisHeredia
# Processing Image - 92 in GenesisHeredia
# Processing Image - 93 in GenesisHeredia
# Processing Image - 94 in GenesisHeredia
# Processing Image - 95 in GenesisHeredia
# Processing Image - 96 in GenesisHeredia
# Processing Image - 97 in GenesisHeredia
# Processing Image - 98 in GenesisHeredia
# Processing Image - 99 in GenesisHeredia
# Processing Image - 100 in GenesisHeredia
# Processing Image - 1 in GoyesAnthony
# Processing Image - 2 in GoyesAnthony
# Processing Image - 3 in GoyesAnthony
# Processing Image - 4 in GoyesAnthony
# Processing Image - 5 in GoyesAnthony
# Processing Image - 6 in GoyesAnthony
# Processing Image - 7 in GoyesAnthony
# Processing Image - 8 in GoyesAnthony
# Processing Image - 9 in GoyesAnthony
# Processing Image - 10 in GoyesAnthony
# Processing Image - 11 in GoyesAnthony
# Processing Image - 12 in GoyesAnthony
# Processing Image - 13 in GoyesAnthony
# Processing Image - 14 in GoyesAnthony
# Processing Image - 15 in GoyesAnthony
# Processing Image - 16 in GoyesAnthony
# Processing Image - 17 in GoyesAnthony
# Processing Image - 18 in GoyesAnthony
# Processing Image - 19 in GoyesAnthony
# Processing Image - 20 in GoyesAnthony
# Processing Image - 21 in GoyesAnthony
# Processing Image - 22 in GoyesAnthony
# Processing Image - 23 in GoyesAnthony
# Processing Image - 24 in GoyesAnthony
# Processing Image - 25 in GoyesAnthony
# Processing Image - 26 in GoyesAnthony
# Processing Image - 27 in GoyesAnthony
# Processing Image - 28 in GoyesAnthony
# Processing Image - 29 in GoyesAnthony
# Processing Image - 30 in GoyesAnthony
# Processing Image - 31 in GoyesAnthony
# Processing Image - 32 in GoyesAnthony
# Processing Image - 33 in GoyesAnthony
# Processing Image - 34 in GoyesAnthony
# Processing Image - 35 in GoyesAnthony
# Processing Image - 36 in GoyesAnthony
# Processing Image - 37 in GoyesAnthony
# Processing Image - 38 in GoyesAnthony
# Processing Image - 39 in GoyesAnthony
# Processing Image - 40 in GoyesAnthony
# Processing Image - 41 in GoyesAnthony
# Processing Image - 42 in GoyesAnthony
# Processing Image - 43 in GoyesAnthony
# Processing Image - 44 in GoyesAnthony
# Processing Image - 45 in GoyesAnthony
# Processing Image - 46 in GoyesAnthony
# Processing Image - 47 in GoyesAnthony
# Processing Image - 48 in GoyesAnthony
# Processing Image - 49 in GoyesAnthony
# Processing Image - 50 in GoyesAnthony
# Processing Image - 51 in GoyesAnthony
# Processing Image - 52 in GoyesAnthony
# Processing Image - 53 in GoyesAnthony
# Processing Image - 54 in GoyesAnthony
# Processing Image - 55 in GoyesAnthony
# Processing Image - 56 in GoyesAnthony
# Processing Image - 57 in GoyesAnthony
# Processing Image - 58 in GoyesAnthony
# Processing Image - 59 in GoyesAnthony
# Processing Image - 60 in GoyesAnthony
# Processing Image - 61 in GoyesAnthony
# Processing Image - 62 in GoyesAnthony
# Processing Image - 63 in GoyesAnthony
# Processing Image - 64 in GoyesAnthony
# Processing Image - 65 in GoyesAnthony
# Processing Image - 66 in GoyesAnthony
# Processing Image - 67 in GoyesAnthony
# Processing Image - 68 in GoyesAnthony
# Processing Image - 69 in GoyesAnthony
# Processing Image - 70 in GoyesAnthony
# Processing Image - 71 in GoyesAnthony
# Processing Image - 72 in GoyesAnthony
# Processing Image - 73 in GoyesAnthony
# Processing Image - 74 in GoyesAnthony
# Processing Image - 75 in GoyesAnthony
# Processing Image - 76 in GoyesAnthony
# Processing Image - 77 in GoyesAnthony
# Processing Image - 78 in GoyesAnthony
# Processing Image - 79 in GoyesAnthony
# Processing Image - 80 in GoyesAnthony
# Processing Image - 81 in GoyesAnthony
# Processing Image - 82 in GoyesAnthony
# Processing Image - 83 in GoyesAnthony
# Processing Image - 84 in GoyesAnthony
# Processing Image - 85 in GoyesAnthony
# Processing Image - 86 in GoyesAnthony
# Processing Image - 87 in GoyesAnthony
# Processing Image - 88 in GoyesAnthony
# Processing Image - 89 in GoyesAnthony
# Processing Image - 90 in GoyesAnthony
# Processing Image - 91 in GoyesAnthony
# Processing Image - 92 in GoyesAnthony
# Processing Image - 93 in GoyesAnthony
# Processing Image - 94 in GoyesAnthony
# Processing Image - 95 in GoyesAnthony
# Processing Image - 96 in GoyesAnthony
# Processing Image - 97 in GoyesAnthony
# Processing Image - 98 in GoyesAnthony
# Processing Image - 99 in GoyesAnthony
# Processing Image - 1 in Jhon Zambrano
# Processing Image - 2 in Jhon Zambrano
# Processing Image - 3 in Jhon Zambrano
# Processing Image - 4 in Jhon Zambrano
# Processing Image - 5 in Jhon Zambrano
# Processing Image - 6 in Jhon Zambrano
# Processing Image - 7 in Jhon Zambrano
# Processing Image - 8 in Jhon Zambrano
# Processing Image - 9 in Jhon Zambrano
# Processing Image - 10 in Jhon Zambrano
# Processing Image - 11 in Jhon Zambrano
# Processing Image - 12 in Jhon Zambrano
# Processing Image - 13 in Jhon Zambrano
# Processing Image - 14 in Jhon Zambrano
# Processing Image - 15 in Jhon Zambrano
# Processing Image - 16 in Jhon Zambrano
# Processing Image - 17 in Jhon Zambrano
# Processing Image - 18 in Jhon Zambrano
# Processing Image - 19 in Jhon Zambrano
# Processing Image - 20 in Jhon Zambrano
# Processing Image - 21 in Jhon Zambrano
# Processing Image - 22 in Jhon Zambrano
# Processing Image - 23 in Jhon Zambrano
# Processing Image - 24 in Jhon Zambrano
# Processing Image - 25 in Jhon Zambrano
# Processing Image - 26 in Jhon Zambrano
# Processing Image - 27 in Jhon Zambrano
# Processing Image - 28 in Jhon Zambrano
# Processing Image - 29 in Jhon Zambrano
# Processing Image - 30 in Jhon Zambrano
# Processing Image - 31 in Jhon Zambrano
# Processing Image - 32 in Jhon Zambrano
# Processing Image - 33 in Jhon Zambrano
# Processing Image - 34 in Jhon Zambrano
# Processing Image - 35 in Jhon Zambrano
# Processing Image - 36 in Jhon Zambrano
# Processing Image - 37 in Jhon Zambrano
# Processing Image - 38 in Jhon Zambrano
# Processing Image - 39 in Jhon Zambrano
# Processing Image - 40 in Jhon Zambrano
# Processing Image - 41 in Jhon Zambrano
# Processing Image - 42 in Jhon Zambrano
# Processing Image - 43 in Jhon Zambrano
# Processing Image - 44 in Jhon Zambrano
# Processing Image - 45 in Jhon Zambrano
# Processing Image - 46 in Jhon Zambrano
# Processing Image - 47 in Jhon Zambrano
# Processing Image - 48 in Jhon Zambrano
# Processing Image - 49 in Jhon Zambrano
# Processing Image - 50 in Jhon Zambrano
# Processing Image - 51 in Jhon Zambrano
# Processing Image - 52 in Jhon Zambrano
# Processing Image - 53 in Jhon Zambrano
# Processing Image - 54 in Jhon Zambrano
# Processing Image - 55 in Jhon Zambrano
# Processing Image - 56 in Jhon Zambrano
# Processing Image - 57 in Jhon Zambrano
# Processing Image - 58 in Jhon Zambrano
# Processing Image - 59 in Jhon Zambrano
# Processing Image - 60 in Jhon Zambrano
# Processing Image - 61 in Jhon Zambrano
# Processing Image - 62 in Jhon Zambrano
# Processing Image - 63 in Jhon Zambrano
# Processing Image - 64 in Jhon Zambrano
# Processing Image - 65 in Jhon Zambrano
# Processing Image - 66 in Jhon Zambrano
# Processing Image - 67 in Jhon Zambrano
# Processing Image - 68 in Jhon Zambrano
# Processing Image - 69 in Jhon Zambrano
# Processing Image - 70 in Jhon Zambrano
# Processing Image - 71 in Jhon Zambrano
# Processing Image - 72 in Jhon Zambrano
# Processing Image - 73 in Jhon Zambrano
# Processing Image - 74 in Jhon Zambrano
# Processing Image - 75 in Jhon Zambrano
# Processing Image - 76 in Jhon Zambrano
# Processing Image - 77 in Jhon Zambrano
# Processing Image - 78 in Jhon Zambrano
# Processing Image - 79 in Jhon Zambrano
# Processing Image - 80 in Jhon Zambrano
# Processing Image - 81 in Jhon Zambrano
# Processing Image - 82 in Jhon Zambrano
# Processing Image - 83 in Jhon Zambrano
# Processing Image - 84 in Jhon Zambrano
# Processing Image - 85 in Jhon Zambrano
# Processing Image - 86 in Jhon Zambrano
# Processing Image - 87 in Jhon Zambrano
# Processing Image - 88 in Jhon Zambrano
# Processing Image - 89 in Jhon Zambrano
# Processing Image - 90 in Jhon Zambrano
# Processing Image - 91 in Jhon Zambrano
# Processing Image - 92 in Jhon Zambrano
# Processing Image - 93 in Jhon Zambrano
# Processing Image - 94 in Jhon Zambrano
# Processing Image - 95 in Jhon Zambrano
# Processing Image - 96 in Jhon Zambrano
# Processing Image - 97 in Jhon Zambrano
# Processing Image - 98 in Jhon Zambrano
# Processing Image - 99 in Jhon Zambrano
# Processing Image - 100 in Jhon Zambrano
# Processing Image - 101 in Jhon Zambrano
# Processing Image - 102 in Jhon Zambrano
# Processing Image - 103 in Jhon Zambrano
# Processing Image - 104 in Jhon Zambrano
# Processing Image - 105 in Jhon Zambrano
# Processing Image - 106 in Jhon Zambrano
# Processing Image - 107 in Jhon Zambrano
# Processing Image - 108 in Jhon Zambrano
# Processing Image - 109 in Jhon Zambrano
# Processing Image - 110 in Jhon Zambrano
# Processing Image - 111 in Jhon Zambrano
# Processing Image - 112 in Jhon Zambrano
# Processing Image - 113 in Jhon Zambrano
# Processing Image - 114 in Jhon Zambrano
# Processing Image - 115 in Jhon Zambrano
# Processing Image - 116 in Jhon Zambrano
# Processing Image - 117 in Jhon Zambrano
# Processing Image - 118 in Jhon Zambrano
# Processing Image - 119 in Jhon Zambrano
# Processing Image - 120 in Jhon Zambrano
# Processing Image - 121 in Jhon Zambrano
# Processing Image - 122 in Jhon Zambrano
# Processing Image - 123 in Jhon Zambrano
# Processing Image - 124 in Jhon Zambrano
# Processing Image - 125 in Jhon Zambrano
# Processing Image - 126 in Jhon Zambrano
# Processing Image - 127 in Jhon Zambrano
# Processing Image - 128 in Jhon Zambrano
# Processing Image - 129 in Jhon Zambrano
# Processing Image - 130 in Jhon Zambrano
# Processing Image - 1 in Jordan Espinosa
# Processing Image - 2 in Jordan Espinosa
# Processing Image - 3 in Jordan Espinosa
# Processing Image - 4 in Jordan Espinosa
# Processing Image - 5 in Jordan Espinosa
# Processing Image - 6 in Jordan Espinosa
# Processing Image - 7 in Jordan Espinosa
# Processing Image - 8 in Jordan Espinosa
# Processing Image - 9 in Jordan Espinosa
# Processing Image - 10 in Jordan Espinosa
# Processing Image - 11 in Jordan Espinosa
# Processing Image - 12 in Jordan Espinosa
# Processing Image - 13 in Jordan Espinosa
# Processing Image - 14 in Jordan Espinosa
# Processing Image - 15 in Jordan Espinosa
# Processing Image - 16 in Jordan Espinosa
# Processing Image - 17 in Jordan Espinosa
# Processing Image - 18 in Jordan Espinosa
# Processing Image - 19 in Jordan Espinosa
# Processing Image - 20 in Jordan Espinosa
# Processing Image - 21 in Jordan Espinosa
# Processing Image - 22 in Jordan Espinosa
# Processing Image - 23 in Jordan Espinosa
# Processing Image - 24 in Jordan Espinosa
# Processing Image - 25 in Jordan Espinosa
# Processing Image - 26 in Jordan Espinosa
# Processing Image - 27 in Jordan Espinosa
# Processing Image - 28 in Jordan Espinosa
# Processing Image - 29 in Jordan Espinosa
# Processing Image - 30 in Jordan Espinosa
# Processing Image - 31 in Jordan Espinosa
# Processing Image - 32 in Jordan Espinosa
# Processing Image - 33 in Jordan Espinosa
# Processing Image - 34 in Jordan Espinosa
# Processing Image - 35 in Jordan Espinosa
# Processing Image - 36 in Jordan Espinosa
# Processing Image - 37 in Jordan Espinosa
# Processing Image - 38 in Jordan Espinosa
# Processing Image - 39 in Jordan Espinosa
# Processing Image - 40 in Jordan Espinosa
# Processing Image - 41 in Jordan Espinosa
# Processing Image - 42 in Jordan Espinosa
# Processing Image - 43 in Jordan Espinosa
# Processing Image - 44 in Jordan Espinosa
# Processing Image - 45 in Jordan Espinosa
# Processing Image - 46 in Jordan Espinosa
# Processing Image - 47 in Jordan Espinosa
# Processing Image - 48 in Jordan Espinosa
# Processing Image - 49 in Jordan Espinosa
# Processing Image - 50 in Jordan Espinosa
# Processing Image - 1 in Jorge Borrero
# Processing Image - 2 in Jorge Borrero
# Processing Image - 3 in Jorge Borrero
# Processing Image - 4 in Jorge Borrero
# Processing Image - 5 in Jorge Borrero
# Processing Image - 6 in Jorge Borrero
# Processing Image - 7 in Jorge Borrero
# Processing Image - 8 in Jorge Borrero
# Processing Image - 9 in Jorge Borrero
# Processing Image - 10 in Jorge Borrero
# Processing Image - 11 in Jorge Borrero
# Processing Image - 12 in Jorge Borrero
# Processing Image - 13 in Jorge Borrero
# Processing Image - 14 in Jorge Borrero
# Processing Image - 15 in Jorge Borrero
# Processing Image - 16 in Jorge Borrero
# Processing Image - 17 in Jorge Borrero
# Processing Image - 18 in Jorge Borrero
# Processing Image - 19 in Jorge Borrero
# Processing Image - 20 in Jorge Borrero
# Processing Image - 21 in Jorge Borrero
# Processing Image - 22 in Jorge Borrero
# Processing Image - 23 in Jorge Borrero
# Processing Image - 24 in Jorge Borrero
# Processing Image - 25 in Jorge Borrero
# Processing Image - 26 in Jorge Borrero
# Processing Image - 27 in Jorge Borrero
# Processing Image - 28 in Jorge Borrero
# Processing Image - 29 in Jorge Borrero
# Processing Image - 30 in Jorge Borrero
# Processing Image - 1 in JoseRuiz
# Processing Image - 2 in JoseRuiz
# Processing Image - 3 in JoseRuiz
# Processing Image - 4 in JoseRuiz
# Processing Image - 5 in JoseRuiz
# Processing Image - 6 in JoseRuiz
# Processing Image - 7 in JoseRuiz
# Processing Image - 8 in JoseRuiz
# Processing Image - 9 in JoseRuiz
# Processing Image - 10 in JoseRuiz
# Processing Image - 11 in JoseRuiz
# Processing Image - 12 in JoseRuiz
# Processing Image - 13 in JoseRuiz
# Processing Image - 14 in JoseRuiz
# Processing Image - 15 in JoseRuiz
# Processing Image - 16 in JoseRuiz
# Processing Image - 17 in JoseRuiz
# Processing Image - 18 in JoseRuiz
# Processing Image - 19 in JoseRuiz
# Processing Image - 20 in JoseRuiz
# Processing Image - 21 in JoseRuiz
# Processing Image - 22 in JoseRuiz
# Processing Image - 23 in JoseRuiz
# Processing Image - 24 in JoseRuiz
# Processing Image - 25 in JoseRuiz
# Processing Image - 26 in JoseRuiz
# Processing Image - 27 in JoseRuiz
# Processing Image - 28 in JoseRuiz
# Processing Image - 29 in JoseRuiz
# Processing Image - 30 in JoseRuiz
# Processing Image - 31 in JoseRuiz
# Processing Image - 32 in JoseRuiz
# Processing Image - 33 in JoseRuiz
# Processing Image - 34 in JoseRuiz
# Processing Image - 35 in JoseRuiz
# Processing Image - 36 in JoseRuiz
# Processing Image - 37 in JoseRuiz
# Processing Image - 38 in JoseRuiz
# Processing Image - 39 in JoseRuiz
# Processing Image - 40 in JoseRuiz
# Processing Image - 41 in JoseRuiz
# Processing Image - 42 in JoseRuiz
# Processing Image - 43 in JoseRuiz
# Processing Image - 44 in JoseRuiz
# Processing Image - 45 in JoseRuiz
# Processing Image - 46 in JoseRuiz
# Processing Image - 47 in JoseRuiz
# Processing Image - 48 in JoseRuiz
# Processing Image - 49 in JoseRuiz
# Processing Image - 50 in JoseRuiz
# Processing Image - 51 in JoseRuiz
# Processing Image - 52 in JoseRuiz
# Processing Image - 53 in JoseRuiz
# Processing Image - 54 in JoseRuiz
# Processing Image - 55 in JoseRuiz
# Processing Image - 56 in JoseRuiz
# Processing Image - 57 in JoseRuiz
# Processing Image - 58 in JoseRuiz
# Processing Image - 59 in JoseRuiz
# Processing Image - 60 in JoseRuiz
# Processing Image - 61 in JoseRuiz
# Processing Image - 62 in JoseRuiz
# Processing Image - 63 in JoseRuiz
# Processing Image - 64 in JoseRuiz
# Processing Image - 65 in JoseRuiz
# Processing Image - 66 in JoseRuiz
# Processing Image - 67 in JoseRuiz
# Processing Image - 68 in JoseRuiz
# Processing Image - 69 in JoseRuiz
# Processing Image - 70 in JoseRuiz
# Processing Image - 71 in JoseRuiz
# Processing Image - 72 in JoseRuiz
# Processing Image - 73 in JoseRuiz
# Processing Image - 74 in JoseRuiz
# Processing Image - 75 in JoseRuiz
# Processing Image - 76 in JoseRuiz
# Processing Image - 77 in JoseRuiz
# Processing Image - 78 in JoseRuiz
# Processing Image - 79 in JoseRuiz
# Processing Image - 80 in JoseRuiz
# Processing Image - 81 in JoseRuiz
# Processing Image - 82 in JoseRuiz
# Processing Image - 83 in JoseRuiz
# Processing Image - 84 in JoseRuiz
# Processing Image - 85 in JoseRuiz
# Processing Image - 86 in JoseRuiz
# Processing Image - 87 in JoseRuiz
# Processing Image - 88 in JoseRuiz
# Processing Image - 89 in JoseRuiz
# Processing Image - 90 in JoseRuiz
# Processing Image - 91 in JoseRuiz
# Processing Image - 92 in JoseRuiz
# Processing Image - 93 in JoseRuiz
# Processing Image - 94 in JoseRuiz
# Processing Image - 95 in JoseRuiz
# Processing Image - 96 in JoseRuiz
# Processing Image - 97 in JoseRuiz
# Processing Image - 98 in JoseRuiz
# Processing Image - 99 in JoseRuiz
# Processing Image - 100 in JoseRuiz
# Processing Image - 1 in LucioCarlos
# Processing Image - 2 in LucioCarlos
# Processing Image - 3 in LucioCarlos
# Processing Image - 4 in LucioCarlos
# Processing Image - 5 in LucioCarlos
# Processing Image - 6 in LucioCarlos
# Processing Image - 7 in LucioCarlos
# Processing Image - 8 in LucioCarlos
# Processing Image - 9 in LucioCarlos
# Processing Image - 10 in LucioCarlos
# Processing Image - 11 in LucioCarlos
# Processing Image - 12 in LucioCarlos
# Processing Image - 13 in LucioCarlos
# Processing Image - 14 in LucioCarlos
# Processing Image - 15 in LucioCarlos
# Processing Image - 16 in LucioCarlos
# Processing Image - 17 in LucioCarlos
# Processing Image - 18 in LucioCarlos
# Processing Image - 19 in LucioCarlos
# Processing Image - 20 in LucioCarlos
# Processing Image - 21 in LucioCarlos
# Processing Image - 22 in LucioCarlos
# Processing Image - 23 in LucioCarlos
# Processing Image - 24 in LucioCarlos
# Processing Image - 25 in LucioCarlos
# Processing Image - 26 in LucioCarlos
# Processing Image - 27 in LucioCarlos
# Processing Image - 28 in LucioCarlos
# Processing Image - 29 in LucioCarlos
# Processing Image - 30 in LucioCarlos
# Processing Image - 31 in LucioCarlos
# Processing Image - 32 in LucioCarlos
# Processing Image - 33 in LucioCarlos
# Processing Image - 34 in LucioCarlos
# Processing Image - 35 in LucioCarlos
# Processing Image - 36 in LucioCarlos
# Processing Image - 37 in LucioCarlos
# Processing Image - 38 in LucioCarlos
# Processing Image - 39 in LucioCarlos
# Processing Image - 40 in LucioCarlos
# Processing Image - 41 in LucioCarlos
# Processing Image - 42 in LucioCarlos
# Processing Image - 43 in LucioCarlos
# Processing Image - 44 in LucioCarlos
# Processing Image - 45 in LucioCarlos
# Processing Image - 46 in LucioCarlos
# Processing Image - 47 in LucioCarlos
# Processing Image - 48 in LucioCarlos
# Processing Image - 49 in LucioCarlos
# Processing Image - 50 in LucioCarlos
# Processing Image - 51 in LucioCarlos
# Processing Image - 52 in LucioCarlos
# Processing Image - 53 in LucioCarlos
# Processing Image - 54 in LucioCarlos
# Processing Image - 55 in LucioCarlos
# Processing Image - 56 in LucioCarlos
# Processing Image - 57 in LucioCarlos
# Processing Image - 58 in LucioCarlos
# Processing Image - 59 in LucioCarlos
# Processing Image - 60 in LucioCarlos
# Processing Image - 61 in LucioCarlos
# Processing Image - 62 in LucioCarlos
# Processing Image - 63 in LucioCarlos
# Processing Image - 64 in LucioCarlos
# Processing Image - 65 in LucioCarlos
# Processing Image - 66 in LucioCarlos
# Processing Image - 67 in LucioCarlos
# Processing Image - 68 in LucioCarlos
# Processing Image - 69 in LucioCarlos
# Processing Image - 70 in LucioCarlos
# Processing Image - 71 in LucioCarlos
# Processing Image - 72 in LucioCarlos
# Processing Image - 73 in LucioCarlos
# Processing Image - 74 in LucioCarlos
# Processing Image - 75 in LucioCarlos
# Processing Image - 76 in LucioCarlos
# Processing Image - 77 in LucioCarlos
# Processing Image - 78 in LucioCarlos
# Processing Image - 79 in LucioCarlos
# Processing Image - 80 in LucioCarlos
# Processing Image - 81 in LucioCarlos
# Processing Image - 82 in LucioCarlos
# Processing Image - 83 in LucioCarlos
# Processing Image - 84 in LucioCarlos
# Processing Image - 85 in LucioCarlos
# Processing Image - 86 in LucioCarlos
# Processing Image - 87 in LucioCarlos
# Processing Image - 88 in LucioCarlos
# Processing Image - 89 in LucioCarlos
# Processing Image - 90 in LucioCarlos
# Processing Image - 91 in LucioCarlos
# Processing Image - 92 in LucioCarlos
# Processing Image - 93 in LucioCarlos
# Processing Image - 94 in LucioCarlos
# Processing Image - 95 in LucioCarlos
# Processing Image - 96 in LucioCarlos
# Processing Image - 97 in LucioCarlos
# Processing Image - 98 in LucioCarlos
# Processing Image - 99 in LucioCarlos
# Processing Image - 100 in LucioCarlos
# Processing Image - 1 in MasacheFernando
# Processing Image - 2 in MasacheFernando
# Processing Image - 3 in MasacheFernando
# Processing Image - 4 in MasacheFernando
# Processing Image - 5 in MasacheFernando
# Processing Image - 6 in MasacheFernando
# Processing Image - 7 in MasacheFernando
# Processing Image - 8 in MasacheFernando
# Processing Image - 9 in MasacheFernando
# Processing Image - 10 in MasacheFernando
# Processing Image - 11 in MasacheFernando
# Processing Image - 12 in MasacheFernando
# Processing Image - 13 in MasacheFernando
# Processing Image - 14 in MasacheFernando
# Processing Image - 15 in MasacheFernando
# Processing Image - 16 in MasacheFernando
# Processing Image - 17 in MasacheFernando
# Processing Image - 18 in MasacheFernando
# Processing Image - 19 in MasacheFernando
# Processing Image - 20 in MasacheFernando
# Processing Image - 21 in MasacheFernando
# Processing Image - 22 in MasacheFernando
# Processing Image - 23 in MasacheFernando
# Processing Image - 24 in MasacheFernando
# Processing Image - 25 in MasacheFernando
# Processing Image - 26 in MasacheFernando
# Processing Image - 27 in MasacheFernando
# Processing Image - 28 in MasacheFernando
# Processing Image - 29 in MasacheFernando
# Processing Image - 30 in MasacheFernando
# Processing Image - 31 in MasacheFernando
# Processing Image - 32 in MasacheFernando
# Processing Image - 33 in MasacheFernando
# Processing Image - 34 in MasacheFernando
# Processing Image - 35 in MasacheFernando
# Processing Image - 36 in MasacheFernando
# Processing Image - 37 in MasacheFernando
# Processing Image - 38 in MasacheFernando
# Processing Image - 39 in MasacheFernando
# Processing Image - 40 in MasacheFernando
# Processing Image - 41 in MasacheFernando
# Processing Image - 42 in MasacheFernando
# Processing Image - 43 in MasacheFernando
# Processing Image - 44 in MasacheFernando
# Processing Image - 45 in MasacheFernando
# Processing Image - 46 in MasacheFernando
# Processing Image - 47 in MasacheFernando
# Processing Image - 48 in MasacheFernando
# Processing Image - 49 in MasacheFernando
# Processing Image - 50 in MasacheFernando
# Processing Image - 51 in MasacheFernando
# Processing Image - 52 in MasacheFernando
# Processing Image - 53 in MasacheFernando
# Processing Image - 54 in MasacheFernando
# Processing Image - 55 in MasacheFernando
# Processing Image - 56 in MasacheFernando
# Processing Image - 57 in MasacheFernando
# Processing Image - 58 in MasacheFernando
# Processing Image - 59 in MasacheFernando
# Processing Image - 60 in MasacheFernando
# Processing Image - 61 in MasacheFernando
# Processing Image - 62 in MasacheFernando
# Processing Image - 63 in MasacheFernando
# Processing Image - 64 in MasacheFernando
# Processing Image - 65 in MasacheFernando
# Processing Image - 66 in MasacheFernando
# Processing Image - 67 in MasacheFernando
# Processing Image - 68 in MasacheFernando
# Processing Image - 69 in MasacheFernando
# Processing Image - 70 in MasacheFernando
# Processing Image - 1 in MelanyLopez
# Processing Image - 2 in MelanyLopez
# Processing Image - 3 in MelanyLopez
# Processing Image - 4 in MelanyLopez
# Processing Image - 5 in MelanyLopez
# Processing Image - 6 in MelanyLopez
# Processing Image - 7 in MelanyLopez
# Processing Image - 8 in MelanyLopez
# Processing Image - 9 in MelanyLopez
# Processing Image - 10 in MelanyLopez
# Processing Image - 11 in MelanyLopez
# Processing Image - 12 in MelanyLopez
# Processing Image - 13 in MelanyLopez
# Processing Image - 14 in MelanyLopez
# Processing Image - 15 in MelanyLopez
# Processing Image - 16 in MelanyLopez
# Processing Image - 17 in MelanyLopez
# Processing Image - 18 in MelanyLopez
# Processing Image - 19 in MelanyLopez
# Processing Image - 20 in MelanyLopez
# Processing Image - 21 in MelanyLopez
# Processing Image - 22 in MelanyLopez
# Processing Image - 23 in MelanyLopez
# Processing Image - 24 in MelanyLopez
# Processing Image - 25 in MelanyLopez
# Processing Image - 26 in MelanyLopez
# Processing Image - 27 in MelanyLopez
# Processing Image - 28 in MelanyLopez
# Processing Image - 29 in MelanyLopez
# Processing Image - 30 in MelanyLopez
# Processing Image - 31 in MelanyLopez
# Processing Image - 32 in MelanyLopez
# Processing Image - 33 in MelanyLopez
# Processing Image - 34 in MelanyLopez
# Processing Image - 35 in MelanyLopez
# Processing Image - 36 in MelanyLopez
# Processing Image - 37 in MelanyLopez
# Processing Image - 38 in MelanyLopez
# Processing Image - 39 in MelanyLopez
# Processing Image - 40 in MelanyLopez
# Processing Image - 41 in MelanyLopez
# Processing Image - 42 in MelanyLopez
# Processing Image - 43 in MelanyLopez
# Processing Image - 44 in MelanyLopez
# Processing Image - 45 in MelanyLopez
# Processing Image - 46 in MelanyLopez
# Processing Image - 47 in MelanyLopez
# Processing Image - 48 in MelanyLopez
# Processing Image - 49 in MelanyLopez
# Processing Image - 50 in MelanyLopez
# Processing Image - 51 in MelanyLopez
# Processing Image - 52 in MelanyLopez
# Processing Image - 53 in MelanyLopez
# Processing Image - 54 in MelanyLopez
# Processing Image - 55 in MelanyLopez
# Processing Image - 56 in MelanyLopez
# Processing Image - 57 in MelanyLopez
# Processing Image - 58 in MelanyLopez
# Processing Image - 59 in MelanyLopez
# Processing Image - 60 in MelanyLopez
# Processing Image - 61 in MelanyLopez
# Processing Image - 62 in MelanyLopez
# Processing Image - 63 in MelanyLopez
# Processing Image - 64 in MelanyLopez
# Processing Image - 65 in MelanyLopez
# Processing Image - 66 in MelanyLopez
# Processing Image - 67 in MelanyLopez
# Processing Image - 68 in MelanyLopez
# Processing Image - 69 in MelanyLopez
# Processing Image - 70 in MelanyLopez
# Processing Image - 71 in MelanyLopez
# Processing Image - 72 in MelanyLopez
# Processing Image - 73 in MelanyLopez
# Processing Image - 74 in MelanyLopez
# Processing Image - 75 in MelanyLopez
# Processing Image - 76 in MelanyLopez
# Processing Image - 77 in MelanyLopez
# Processing Image - 78 in MelanyLopez
# Processing Image - 79 in MelanyLopez
# Processing Image - 80 in MelanyLopez
# Processing Image - 81 in MelanyLopez
# Processing Image - 82 in MelanyLopez
# Processing Image - 83 in MelanyLopez
# Processing Image - 84 in MelanyLopez
# Processing Image - 85 in MelanyLopez
# Processing Image - 86 in MelanyLopez
# Processing Image - 87 in MelanyLopez
# Processing Image - 88 in MelanyLopez
# Processing Image - 89 in MelanyLopez
# Processing Image - 90 in MelanyLopez
# Processing Image - 91 in MelanyLopez
# Processing Image - 92 in MelanyLopez
# Processing Image - 93 in MelanyLopez
# Processing Image - 94 in MelanyLopez
# Processing Image - 95 in MelanyLopez
# Processing Image - 96 in MelanyLopez
# Processing Image - 97 in MelanyLopez
# Processing Image - 98 in MelanyLopez
# Processing Image - 99 in MelanyLopez
# Processing Image - 100 in MelanyLopez
# Processing Image - 101 in MelanyLopez
# Processing Image - 102 in MelanyLopez
# Processing Image - 103 in MelanyLopez
# Processing Image - 104 in MelanyLopez
# Processing Image - 105 in MelanyLopez
# Processing Image - 106 in MelanyLopez
# Processing Image - 107 in MelanyLopez
# Processing Image - 108 in MelanyLopez
# Processing Image - 109 in MelanyLopez
# Processing Image - 110 in MelanyLopez
# Processing Image - 1 in MosqueraLucy
# Processing Image - 2 in MosqueraLucy
# Processing Image - 3 in MosqueraLucy
# Processing Image - 4 in MosqueraLucy
# Processing Image - 5 in MosqueraLucy
# Processing Image - 6 in MosqueraLucy
# Processing Image - 7 in MosqueraLucy
# Processing Image - 8 in MosqueraLucy
# Processing Image - 9 in MosqueraLucy
# Processing Image - 10 in MosqueraLucy
# Processing Image - 11 in MosqueraLucy
# Processing Image - 12 in MosqueraLucy
# Processing Image - 13 in MosqueraLucy
# Processing Image - 14 in MosqueraLucy
# Processing Image - 15 in MosqueraLucy
# Processing Image - 16 in MosqueraLucy
# Processing Image - 17 in MosqueraLucy
# Processing Image - 18 in MosqueraLucy
# Processing Image - 19 in MosqueraLucy
# Processing Image - 20 in MosqueraLucy
# Processing Image - 21 in MosqueraLucy
# Processing Image - 22 in MosqueraLucy
# Processing Image - 23 in MosqueraLucy
# Processing Image - 24 in MosqueraLucy
# Processing Image - 25 in MosqueraLucy
# Processing Image - 26 in MosqueraLucy
# Processing Image - 27 in MosqueraLucy
# Processing Image - 28 in MosqueraLucy
# Processing Image - 29 in MosqueraLucy
# Processing Image - 30 in MosqueraLucy
# Processing Image - 31 in MosqueraLucy
# Processing Image - 32 in MosqueraLucy
# Processing Image - 33 in MosqueraLucy
# Processing Image - 34 in MosqueraLucy
# Processing Image - 35 in MosqueraLucy
# Processing Image - 36 in MosqueraLucy
# Processing Image - 37 in MosqueraLucy
# Processing Image - 38 in MosqueraLucy
# Processing Image - 39 in MosqueraLucy
# Processing Image - 40 in MosqueraLucy
# Processing Image - 41 in MosqueraLucy
# Processing Image - 42 in MosqueraLucy
# Processing Image - 43 in MosqueraLucy
# Processing Image - 44 in MosqueraLucy
# Processing Image - 45 in MosqueraLucy
# Processing Image - 46 in MosqueraLucy
# Processing Image - 47 in MosqueraLucy
# Processing Image - 48 in MosqueraLucy
# Processing Image - 49 in MosqueraLucy
# Processing Image - 50 in MosqueraLucy
# Processing Image - 51 in MosqueraLucy
# Processing Image - 52 in MosqueraLucy
# Processing Image - 53 in MosqueraLucy
# Processing Image - 54 in MosqueraLucy
# Processing Image - 55 in MosqueraLucy
# Processing Image - 56 in MosqueraLucy
# Processing Image - 57 in MosqueraLucy
# Processing Image - 58 in MosqueraLucy
# Processing Image - 59 in MosqueraLucy
# Processing Image - 60 in MosqueraLucy
# Processing Image - 61 in MosqueraLucy
# Processing Image - 62 in MosqueraLucy
# Processing Image - 63 in MosqueraLucy
# Processing Image - 64 in MosqueraLucy
# Processing Image - 65 in MosqueraLucy
# Processing Image - 66 in MosqueraLucy
# Processing Image - 67 in MosqueraLucy
# Processing Image - 68 in MosqueraLucy
# Processing Image - 69 in MosqueraLucy
# Processing Image - 70 in MosqueraLucy
# Processing Image - 71 in MosqueraLucy
# Processing Image - 72 in MosqueraLucy
# Processing Image - 73 in MosqueraLucy
# Processing Image - 74 in MosqueraLucy
# Processing Image - 75 in MosqueraLucy
# Processing Image - 76 in MosqueraLucy
# Processing Image - 77 in MosqueraLucy
# Processing Image - 78 in MosqueraLucy
# Processing Image - 79 in MosqueraLucy
# Processing Image - 80 in MosqueraLucy
# Processing Image - 81 in MosqueraLucy
# Processing Image - 82 in MosqueraLucy
# Processing Image - 83 in MosqueraLucy
# Processing Image - 84 in MosqueraLucy
# Processing Image - 85 in MosqueraLucy
# Processing Image - 86 in MosqueraLucy
# Processing Image - 87 in MosqueraLucy
# Processing Image - 88 in MosqueraLucy
# Processing Image - 89 in MosqueraLucy
# Processing Image - 90 in MosqueraLucy
# Processing Image - 91 in MosqueraLucy
# Processing Image - 92 in MosqueraLucy
# Processing Image - 93 in MosqueraLucy
# Processing Image - 94 in MosqueraLucy
# Processing Image - 95 in MosqueraLucy
# Processing Image - 96 in MosqueraLucy
# Processing Image - 97 in MosqueraLucy
# Processing Image - 98 in MosqueraLucy
# Processing Image - 99 in MosqueraLucy
# Processing Image - 100 in MosqueraLucy
# Processing Image - 101 in MosqueraLucy
# Processing Image - 102 in MosqueraLucy
# Processing Image - 103 in MosqueraLucy
# Processing Image - 104 in MosqueraLucy
# Processing Image - 105 in MosqueraLucy
# Processing Image - 106 in MosqueraLucy
# Processing Image - 107 in MosqueraLucy
# Processing Image - 108 in MosqueraLucy
# Processing Image - 109 in MosqueraLucy
# Processing Image - 110 in MosqueraLucy
# Processing Image - 111 in MosqueraLucy
# Processing Image - 112 in MosqueraLucy
# Processing Image - 113 in MosqueraLucy
# Processing Image - 114 in MosqueraLucy
# Processing Image - 115 in MosqueraLucy
# Processing Image - 116 in MosqueraLucy
# Processing Image - 117 in MosqueraLucy
# Processing Image - 118 in MosqueraLucy
# Processing Image - 119 in MosqueraLucy
# Processing Image - 120 in MosqueraLucy
# Processing Image - 121 in MosqueraLucy
# Processing Image - 122 in MosqueraLucy
# Processing Image - 123 in MosqueraLucy
# Processing Image - 124 in MosqueraLucy
# Processing Image - 125 in MosqueraLucy
# Processing Image - 126 in MosqueraLucy
# Processing Image - 127 in MosqueraLucy
# Processing Image - 128 in MosqueraLucy
# Processing Image - 129 in MosqueraLucy
# Processing Image - 130 in MosqueraLucy
# Processing Image - 131 in MosqueraLucy
# Processing Image - 132 in MosqueraLucy
# Processing Image - 133 in MosqueraLucy
# Processing Image - 134 in MosqueraLucy
# Processing Image - 135 in MosqueraLucy
# Processing Image - 136 in MosqueraLucy
# Processing Image - 137 in MosqueraLucy
# Processing Image - 138 in MosqueraLucy
# Processing Image - 139 in MosqueraLucy
# Processing Image - 140 in MosqueraLucy
# Processing Image - 141 in MosqueraLucy
# Processing Image - 142 in MosqueraLucy
# Processing Image - 143 in MosqueraLucy
# Processing Image - 144 in MosqueraLucy
# Processing Image - 145 in MosqueraLucy
# Processing Image - 146 in MosqueraLucy
# Processing Image - 147 in MosqueraLucy
# Processing Image - 148 in MosqueraLucy
# Processing Image - 149 in MosqueraLucy
# Processing Image - 150 in MosqueraLucy
# Processing Image - 151 in MosqueraLucy
# Processing Image - 152 in MosqueraLucy
# Processing Image - 153 in MosqueraLucy
# Processing Image - 154 in MosqueraLucy
# Processing Image - 155 in MosqueraLucy
# Processing Image - 156 in MosqueraLucy
# Processing Image - 157 in MosqueraLucy
# Processing Image - 158 in MosqueraLucy
# Processing Image - 159 in MosqueraLucy
# Processing Image - 160 in MosqueraLucy
# Processing Image - 161 in MosqueraLucy
# Processing Image - 162 in MosqueraLucy
# Processing Image - 163 in MosqueraLucy
# Processing Image - 164 in MosqueraLucy
# Processing Image - 165 in MosqueraLucy
# Processing Image - 166 in MosqueraLucy
# Processing Image - 167 in MosqueraLucy
# Processing Image - 168 in MosqueraLucy
# Processing Image - 169 in MosqueraLucy
# Processing Image - 170 in MosqueraLucy
# Processing Image - 171 in MosqueraLucy
# Processing Image - 172 in MosqueraLucy
# Processing Image - 173 in MosqueraLucy
# Processing Image - 174 in MosqueraLucy
# Processing Image - 175 in MosqueraLucy
# Processing Image - 176 in MosqueraLucy
# Processing Image - 177 in MosqueraLucy
# Processing Image - 178 in MosqueraLucy
# Processing Image - 179 in MosqueraLucy
# Processing Image - 180 in MosqueraLucy
# Processing Image - 181 in MosqueraLucy
# Processing Image - 182 in MosqueraLucy
# Processing Image - 183 in MosqueraLucy
# Processing Image - 184 in MosqueraLucy
# Processing Image - 185 in MosqueraLucy
# Processing Image - 186 in MosqueraLucy
# Processing Image - 187 in MosqueraLucy
# Processing Image - 188 in MosqueraLucy
# Processing Image - 189 in MosqueraLucy
# Processing Image - 190 in MosqueraLucy
# Processing Image - 191 in MosqueraLucy
# Processing Image - 192 in MosqueraLucy
# Processing Image - 193 in MosqueraLucy
# Processing Image - 194 in MosqueraLucy
# Processing Image - 195 in MosqueraLucy
# Processing Image - 196 in MosqueraLucy
# Processing Image - 197 in MosqueraLucy
# Processing Image - 198 in MosqueraLucy
# Processing Image - 199 in MosqueraLucy
# Processing Image - 200 in MosqueraLucy
# Processing Image - 201 in MosqueraLucy
# Processing Image - 202 in MosqueraLucy
# Processing Image - 203 in MosqueraLucy
# Processing Image - 204 in MosqueraLucy
# Processing Image - 205 in MosqueraLucy
# Processing Image - 206 in MosqueraLucy
# Processing Image - 207 in MosqueraLucy
# Processing Image - 208 in MosqueraLucy
# Processing Image - 209 in MosqueraLucy
# Processing Image - 210 in MosqueraLucy
# Processing Image - 211 in MosqueraLucy
# Processing Image - 212 in MosqueraLucy
# Processing Image - 213 in MosqueraLucy
# Processing Image - 214 in MosqueraLucy
# Processing Image - 215 in MosqueraLucy
# Processing Image - 216 in MosqueraLucy
# Processing Image - 217 in MosqueraLucy
# Processing Image - 218 in MosqueraLucy
# Processing Image - 219 in MosqueraLucy
# Processing Image - 220 in MosqueraLucy
# Processing Image - 221 in MosqueraLucy
# Processing Image - 222 in MosqueraLucy
# Processing Image - 223 in MosqueraLucy
# Processing Image - 224 in MosqueraLucy
# Processing Image - 225 in MosqueraLucy
# Processing Image - 226 in MosqueraLucy
# Processing Image - 227 in MosqueraLucy
# Processing Image - 228 in MosqueraLucy
# Processing Image - 229 in MosqueraLucy
# Processing Image - 230 in MosqueraLucy
# Processing Image - 231 in MosqueraLucy
# Processing Image - 232 in MosqueraLucy
# Processing Image - 233 in MosqueraLucy
# Processing Image - 234 in MosqueraLucy
# Processing Image - 235 in MosqueraLucy
# Processing Image - 236 in MosqueraLucy
# Processing Image - 237 in MosqueraLucy
# Processing Image - 238 in MosqueraLucy
# Processing Image - 239 in MosqueraLucy
# Processing Image - 240 in MosqueraLucy
# Processing Image - 241 in MosqueraLucy
# Processing Image - 242 in MosqueraLucy
# Processing Image - 243 in MosqueraLucy
# Processing Image - 244 in MosqueraLucy
# Processing Image - 245 in MosqueraLucy
# Processing Image - 246 in MosqueraLucy
# Processing Image - 247 in MosqueraLucy
# Processing Image - 248 in MosqueraLucy
# Processing Image - 249 in MosqueraLucy
# Processing Image - 250 in MosqueraLucy
# Processing Image - 251 in MosqueraLucy
# Processing Image - 252 in MosqueraLucy
# Processing Image - 253 in MosqueraLucy
# Processing Image - 254 in MosqueraLucy
# Processing Image - 255 in MosqueraLucy
# Processing Image - 256 in MosqueraLucy
# Processing Image - 257 in MosqueraLucy
# Processing Image - 258 in MosqueraLucy
# Processing Image - 259 in MosqueraLucy
# Processing Image - 260 in MosqueraLucy
# Processing Image - 261 in MosqueraLucy
# Processing Image - 262 in MosqueraLucy
# Processing Image - 263 in MosqueraLucy
# Processing Image - 264 in MosqueraLucy
# Processing Image - 265 in MosqueraLucy
# Processing Image - 266 in MosqueraLucy
# Processing Image - 267 in MosqueraLucy
# Processing Image - 268 in MosqueraLucy
# Processing Image - 269 in MosqueraLucy
# Processing Image - 270 in MosqueraLucy
# Processing Image - 271 in MosqueraLucy
# Processing Image - 272 in MosqueraLucy
# Processing Image - 273 in MosqueraLucy
# Processing Image - 274 in MosqueraLucy
# Processing Image - 275 in MosqueraLucy
# Processing Image - 276 in MosqueraLucy
# Processing Image - 277 in MosqueraLucy
# Processing Image - 278 in MosqueraLucy
# Processing Image - 279 in MosqueraLucy
# Processing Image - 280 in MosqueraLucy
# Processing Image - 281 in MosqueraLucy
# Processing Image - 282 in MosqueraLucy
# Processing Image - 283 in MosqueraLucy
# Processing Image - 284 in MosqueraLucy
# Processing Image - 285 in MosqueraLucy
# Processing Image - 286 in MosqueraLucy
# Processing Image - 287 in MosqueraLucy
# Processing Image - 288 in MosqueraLucy
# Processing Image - 289 in MosqueraLucy
# Processing Image - 290 in MosqueraLucy
# Processing Image - 291 in MosqueraLucy
# Processing Image - 292 in MosqueraLucy
# Processing Image - 293 in MosqueraLucy
# Processing Image - 294 in MosqueraLucy
# Processing Image - 295 in MosqueraLucy
# Processing Image - 296 in MosqueraLucy
# Processing Image - 297 in MosqueraLucy
# Processing Image - 298 in MosqueraLucy
# Processing Image - 299 in MosqueraLucy
# Processing Image - 300 in MosqueraLucy
# Processing Image - 301 in MosqueraLucy
# Processing Image - 302 in MosqueraLucy
# Processing Image - 303 in MosqueraLucy
# Processing Image - 304 in MosqueraLucy
# Processing Image - 305 in MosqueraLucy
# Processing Image - 306 in MosqueraLucy
# Processing Image - 307 in MosqueraLucy
# Processing Image - 308 in MosqueraLucy
# Processing Image - 309 in MosqueraLucy
# Processing Image - 310 in MosqueraLucy
# Processing Image - 311 in MosqueraLucy
# Processing Image - 312 in MosqueraLucy
# Processing Image - 313 in MosqueraLucy
# Processing Image - 314 in MosqueraLucy
# Processing Image - 315 in MosqueraLucy
# Processing Image - 316 in MosqueraLucy
# Processing Image - 317 in MosqueraLucy
# Processing Image - 318 in MosqueraLucy
# Processing Image - 319 in MosqueraLucy
# Processing Image - 320 in MosqueraLucy
# Processing Image - 321 in MosqueraLucy
# Processing Image - 322 in MosqueraLucy
# Processing Image - 323 in MosqueraLucy
# Processing Image - 324 in MosqueraLucy
# Processing Image - 325 in MosqueraLucy
# Processing Image - 326 in MosqueraLucy
# Processing Image - 327 in MosqueraLucy
# Processing Image - 328 in MosqueraLucy
# Processing Image - 329 in MosqueraLucy
# Processing Image - 330 in MosqueraLucy
# Processing Image - 331 in MosqueraLucy
# Processing Image - 332 in MosqueraLucy
# Processing Image - 333 in MosqueraLucy
# Processing Image - 334 in MosqueraLucy
# Processing Image - 335 in MosqueraLucy
# Processing Image - 336 in MosqueraLucy
# Processing Image - 337 in MosqueraLucy
# Processing Image - 338 in MosqueraLucy
# Processing Image - 339 in MosqueraLucy
# Processing Image - 340 in MosqueraLucy
# Processing Image - 341 in MosqueraLucy
# Processing Image - 342 in MosqueraLucy
# Processing Image - 343 in MosqueraLucy
# Processing Image - 344 in MosqueraLucy
# Processing Image - 345 in MosqueraLucy
# Processing Image - 346 in MosqueraLucy
# Processing Image - 347 in MosqueraLucy
# Processing Image - 348 in MosqueraLucy
# Processing Image - 349 in MosqueraLucy
# Processing Image - 350 in MosqueraLucy
# Processing Image - 351 in MosqueraLucy
# Processing Image - 352 in MosqueraLucy
# Processing Image - 353 in MosqueraLucy
# Processing Image - 354 in MosqueraLucy
# Processing Image - 355 in MosqueraLucy
# Processing Image - 356 in MosqueraLucy
# Processing Image - 357 in MosqueraLucy
# Processing Image - 358 in MosqueraLucy
# Processing Image - 359 in MosqueraLucy
# Processing Image - 360 in MosqueraLucy
# Processing Image - 361 in MosqueraLucy
# Processing Image - 362 in MosqueraLucy
# Processing Image - 363 in MosqueraLucy
# Processing Image - 364 in MosqueraLucy
# Processing Image - 365 in MosqueraLucy
# Processing Image - 366 in MosqueraLucy
# Processing Image - 367 in MosqueraLucy
# Processing Image - 368 in MosqueraLucy
# Processing Image - 369 in MosqueraLucy
# Processing Image - 370 in MosqueraLucy
# Processing Image - 371 in MosqueraLucy
# Processing Image - 372 in MosqueraLucy
# Processing Image - 373 in MosqueraLucy
# Processing Image - 374 in MosqueraLucy
# Processing Image - 375 in MosqueraLucy
# Processing Image - 376 in MosqueraLucy
# Processing Image - 377 in MosqueraLucy
# Processing Image - 378 in MosqueraLucy
# Processing Image - 379 in MosqueraLucy
# Processing Image - 380 in MosqueraLucy
# Processing Image - 381 in MosqueraLucy
# Processing Image - 382 in MosqueraLucy
# Processing Image - 383 in MosqueraLucy
# Processing Image - 384 in MosqueraLucy
# Processing Image - 385 in MosqueraLucy
# Processing Image - 386 in MosqueraLucy
# Processing Image - 387 in MosqueraLucy
# Processing Image - 388 in MosqueraLucy
# Processing Image - 389 in MosqueraLucy
# Processing Image - 390 in MosqueraLucy
# Processing Image - 391 in MosqueraLucy
# Processing Image - 392 in MosqueraLucy
# Processing Image - 393 in MosqueraLucy
# Processing Image - 394 in MosqueraLucy
# Processing Image - 395 in MosqueraLucy
# Processing Image - 396 in MosqueraLucy
# Processing Image - 397 in MosqueraLucy
# Processing Image - 398 in MosqueraLucy
# Processing Image - 399 in MosqueraLucy
# Processing Image - 400 in MosqueraLucy
# Processing Image - 401 in MosqueraLucy
# Processing Image - 402 in MosqueraLucy
# Processing Image - 403 in MosqueraLucy
# Processing Image - 404 in MosqueraLucy
# Processing Image - 405 in MosqueraLucy
# Processing Image - 406 in MosqueraLucy
# Processing Image - 407 in MosqueraLucy
# Processing Image - 408 in MosqueraLucy
# Processing Image - 409 in MosqueraLucy
# Processing Image - 410 in MosqueraLucy
# Processing Image - 411 in MosqueraLucy
# Processing Image - 412 in MosqueraLucy
# Processing Image - 413 in MosqueraLucy
# Processing Image - 414 in MosqueraLucy
# Processing Image - 415 in MosqueraLucy
# Processing Image - 416 in MosqueraLucy
# Processing Image - 417 in MosqueraLucy
# Processing Image - 418 in MosqueraLucy
# Processing Image - 419 in MosqueraLucy
# Processing Image - 420 in MosqueraLucy
# Processing Image - 421 in MosqueraLucy
# Processing Image - 422 in MosqueraLucy
# Processing Image - 423 in MosqueraLucy
# Processing Image - 424 in MosqueraLucy
# Processing Image - 425 in MosqueraLucy
# Processing Image - 426 in MosqueraLucy
# Processing Image - 427 in MosqueraLucy
# Processing Image - 428 in MosqueraLucy
# Processing Image - 429 in MosqueraLucy
# Processing Image - 430 in MosqueraLucy
# Processing Image - 431 in MosqueraLucy
# Processing Image - 432 in MosqueraLucy
# Processing Image - 433 in MosqueraLucy
# Processing Image - 434 in MosqueraLucy
# Processing Image - 435 in MosqueraLucy
# Processing Image - 436 in MosqueraLucy
# Processing Image - 437 in MosqueraLucy
# Processing Image - 438 in MosqueraLucy
# Processing Image - 439 in MosqueraLucy
# Processing Image - 440 in MosqueraLucy
# Processing Image - 441 in MosqueraLucy
# Processing Image - 442 in MosqueraLucy
# Processing Image - 443 in MosqueraLucy
# Processing Image - 444 in MosqueraLucy
# Processing Image - 445 in MosqueraLucy
# Processing Image - 446 in MosqueraLucy
# Processing Image - 447 in MosqueraLucy
# Processing Image - 448 in MosqueraLucy
# Processing Image - 449 in MosqueraLucy
# Processing Image - 450 in MosqueraLucy
# Processing Image - 451 in MosqueraLucy
# Processing Image - 452 in MosqueraLucy
# Processing Image - 453 in MosqueraLucy
# Processing Image - 454 in MosqueraLucy
# Processing Image - 455 in MosqueraLucy
# Processing Image - 456 in MosqueraLucy
# Processing Image - 457 in MosqueraLucy
# Processing Image - 458 in MosqueraLucy
# Processing Image - 459 in MosqueraLucy
# Processing Image - 460 in MosqueraLucy
# Processing Image - 461 in MosqueraLucy
# Processing Image - 462 in MosqueraLucy

# %% [markdown]
# ## Eliminacion de fondo

# %%
images_path = "./DESING"
class_names = os.listdir(images_path)
class_names.sort()
print(class_names)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MasacheFernando', 'MelanyLopez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMaria', 'PauteKevin', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %%
""" Procedemos a eliminar el fondo de todas las imagenes a la
cuales se les elimino el ruido. Dichas imagenes se guardaran en la carpeta proyectoIA_rgb  """
for class_name in class_names:
    cur_path = images_path + "/" + class_name
    cur_label = class_name
    i = 1

    for file in glob.glob(cur_path + "/*"):
        print("Processing Image - {} in {}".format(i, cur_label))
        # read the images path
        image = cv2.imread(file)
        # remove bg 
        output = remove(image)
        # save images ruta de la carpeta
        save_path = './PROYECTOrgb/'+ cur_label
        cv2.imwrite(os.path.join(save_path , cur_label + '_' + str(i) + '.jpg'), output)
        

        # show loop update
        i += 1
# Out:
# Processing Image - 1 in Ariel Chabla
# Processing Image - 2 in Ariel Chabla
# Processing Image - 3 in Ariel Chabla
# Processing Image - 4 in Ariel Chabla
# Processing Image - 5 in Ariel Chabla
# Processing Image - 6 in Ariel Chabla
# Processing Image - 7 in Ariel Chabla
# Processing Image - 8 in Ariel Chabla
# Processing Image - 9 in Ariel Chabla
# Processing Image - 10 in Ariel Chabla
# Processing Image - 11 in Ariel Chabla
# Processing Image - 12 in Ariel Chabla
# Processing Image - 13 in Ariel Chabla
# Processing Image - 14 in Ariel Chabla
# Processing Image - 15 in Ariel Chabla
# Processing Image - 16 in Ariel Chabla
# Processing Image - 17 in Ariel Chabla
# Processing Image - 18 in Ariel Chabla
# Processing Image - 19 in Ariel Chabla
# Processing Image - 20 in Ariel Chabla
# Processing Image - 21 in Ariel Chabla
# Processing Image - 22 in Ariel Chabla
# Processing Image - 23 in Ariel Chabla
# Processing Image - 24 in Ariel Chabla
# Processing Image - 25 in Ariel Chabla
# Processing Image - 26 in Ariel Chabla
# Processing Image - 27 in Ariel Chabla
# Processing Image - 28 in Ariel Chabla
# Processing Image - 29 in Ariel Chabla
# Processing Image - 30 in Ariel Chabla
# Processing Image - 31 in Ariel Chabla
# Processing Image - 32 in Ariel Chabla
# Processing Image - 33 in Ariel Chabla
# Processing Image - 34 in Ariel Chabla
# Processing Image - 35 in Ariel Chabla
# Processing Image - 36 in Ariel Chabla
# Processing Image - 37 in Ariel Chabla
# Processing Image - 38 in Ariel Chabla
# Processing Image - 39 in Ariel Chabla
# Processing Image - 40 in Ariel Chabla
# Processing Image - 41 in Ariel Chabla
# Processing Image - 42 in Ariel Chabla
# Processing Image - 43 in Ariel Chabla
# Processing Image - 44 in Ariel Chabla
# Processing Image - 45 in Ariel Chabla
# Processing Image - 46 in Ariel Chabla
# Processing Image - 47 in Ariel Chabla
# Processing Image - 48 in Ariel Chabla
# Processing Image - 49 in Ariel Chabla
# Processing Image - 50 in Ariel Chabla
# Processing Image - 51 in Ariel Chabla
# Processing Image - 52 in Ariel Chabla
# Processing Image - 53 in Ariel Chabla
# Processing Image - 54 in Ariel Chabla
# Processing Image - 55 in Ariel Chabla
# Processing Image - 56 in Ariel Chabla
# Processing Image - 57 in Ariel Chabla
# Processing Image - 58 in Ariel Chabla
# Processing Image - 59 in Ariel Chabla
# Processing Image - 60 in Ariel Chabla
# Processing Image - 61 in Ariel Chabla
# Processing Image - 62 in Ariel Chabla
# Processing Image - 63 in Ariel Chabla
# Processing Image - 64 in Ariel Chabla
# Processing Image - 65 in Ariel Chabla
# Processing Image - 66 in Ariel Chabla
# Processing Image - 67 in Ariel Chabla
# Processing Image - 68 in Ariel Chabla
# Processing Image - 69 in Ariel Chabla
# Processing Image - 70 in Ariel Chabla
# Processing Image - 71 in Ariel Chabla
# Processing Image - 72 in Ariel Chabla
# Processing Image - 73 in Ariel Chabla
# Processing Image - 74 in Ariel Chabla
# Processing Image - 75 in Ariel Chabla
# Processing Image - 76 in Ariel Chabla
# Processing Image - 77 in Ariel Chabla
# Processing Image - 78 in Ariel Chabla
# Processing Image - 79 in Ariel Chabla
# Processing Image - 80 in Ariel Chabla
# Processing Image - 1 in ArroboMercy
# Processing Image - 2 in ArroboMercy
# Processing Image - 3 in ArroboMercy
# Processing Image - 4 in ArroboMercy
# Processing Image - 5 in ArroboMercy
# Processing Image - 6 in ArroboMercy
# Processing Image - 7 in ArroboMercy
# Processing Image - 8 in ArroboMercy
# Processing Image - 9 in ArroboMercy
# Processing Image - 10 in ArroboMercy
# Processing Image - 11 in ArroboMercy
# Processing Image - 12 in ArroboMercy
# Processing Image - 13 in ArroboMercy
# Processing Image - 14 in ArroboMercy
# Processing Image - 15 in ArroboMercy
# Processing Image - 16 in ArroboMercy
# Processing Image - 17 in ArroboMercy
# Processing Image - 18 in ArroboMercy
# Processing Image - 19 in ArroboMercy
# Processing Image - 20 in ArroboMercy
# Processing Image - 21 in ArroboMercy
# Processing Image - 22 in ArroboMercy
# Processing Image - 23 in ArroboMercy
# Processing Image - 24 in ArroboMercy
# Processing Image - 25 in ArroboMercy
# Processing Image - 26 in ArroboMercy
# Processing Image - 27 in ArroboMercy
# Processing Image - 28 in ArroboMercy
# Processing Image - 29 in ArroboMercy
# Processing Image - 30 in ArroboMercy
# Processing Image - 31 in ArroboMercy
# Processing Image - 32 in ArroboMercy
# Processing Image - 33 in ArroboMercy
# Processing Image - 34 in ArroboMercy
# Processing Image - 35 in ArroboMercy
# Processing Image - 36 in ArroboMercy
# Processing Image - 37 in ArroboMercy
# Processing Image - 38 in ArroboMercy
# Processing Image - 39 in ArroboMercy
# Processing Image - 40 in ArroboMercy
# Processing Image - 41 in ArroboMercy
# Processing Image - 42 in ArroboMercy
# Processing Image - 43 in ArroboMercy
# Processing Image - 44 in ArroboMercy
# Processing Image - 45 in ArroboMercy
# Processing Image - 46 in ArroboMercy
# Processing Image - 47 in ArroboMercy
# Processing Image - 48 in ArroboMercy
# Processing Image - 49 in ArroboMercy
# Processing Image - 50 in ArroboMercy
# Processing Image - 51 in ArroboMercy
# Processing Image - 52 in ArroboMercy
# Processing Image - 53 in ArroboMercy
# Processing Image - 54 in ArroboMercy
# Processing Image - 55 in ArroboMercy
# Processing Image - 56 in ArroboMercy
# Processing Image - 57 in ArroboMercy
# Processing Image - 58 in ArroboMercy
# Processing Image - 59 in ArroboMercy
# Processing Image - 60 in ArroboMercy
# Processing Image - 61 in ArroboMercy
# Processing Image - 62 in ArroboMercy
# Processing Image - 63 in ArroboMercy
# Processing Image - 64 in ArroboMercy
# Processing Image - 65 in ArroboMercy
# Processing Image - 66 in ArroboMercy
# Processing Image - 67 in ArroboMercy
# Processing Image - 68 in ArroboMercy
# Processing Image - 69 in ArroboMercy
# Processing Image - 70 in ArroboMercy
# Processing Image - 71 in ArroboMercy
# Processing Image - 72 in ArroboMercy
# Processing Image - 73 in ArroboMercy
# Processing Image - 74 in ArroboMercy
# Processing Image - 75 in ArroboMercy
# Processing Image - 76 in ArroboMercy
# Processing Image - 77 in ArroboMercy
# Processing Image - 78 in ArroboMercy
# Processing Image - 79 in ArroboMercy
# Processing Image - 1 in BarraganSteven
# Processing Image - 2 in BarraganSteven
# Processing Image - 3 in BarraganSteven
# Processing Image - 4 in BarraganSteven
# Processing Image - 5 in BarraganSteven
# Processing Image - 6 in BarraganSteven
# Processing Image - 7 in BarraganSteven
# Processing Image - 8 in BarraganSteven
# Processing Image - 9 in BarraganSteven
# Processing Image - 10 in BarraganSteven
# Processing Image - 11 in BarraganSteven
# Processing Image - 12 in BarraganSteven
# Processing Image - 13 in BarraganSteven
# Processing Image - 14 in BarraganSteven
# Processing Image - 15 in BarraganSteven
# Processing Image - 16 in BarraganSteven
# Processing Image - 17 in BarraganSteven
# Processing Image - 18 in BarraganSteven
# Processing Image - 19 in BarraganSteven
# Processing Image - 20 in BarraganSteven
# Processing Image - 21 in BarraganSteven
# Processing Image - 22 in BarraganSteven
# Processing Image - 23 in BarraganSteven
# Processing Image - 24 in BarraganSteven
# Processing Image - 25 in BarraganSteven
# Processing Image - 26 in BarraganSteven
# Processing Image - 27 in BarraganSteven
# Processing Image - 28 in BarraganSteven
# Processing Image - 29 in BarraganSteven
# Processing Image - 30 in BarraganSteven
# Processing Image - 31 in BarraganSteven
# Processing Image - 32 in BarraganSteven
# Processing Image - 33 in BarraganSteven
# Processing Image - 34 in BarraganSteven
# Processing Image - 35 in BarraganSteven
# Processing Image - 36 in BarraganSteven
# Processing Image - 37 in BarraganSteven
# Processing Image - 38 in BarraganSteven
# Processing Image - 39 in BarraganSteven
# Processing Image - 40 in BarraganSteven
# Processing Image - 41 in BarraganSteven
# Processing Image - 42 in BarraganSteven
# Processing Image - 43 in BarraganSteven
# Processing Image - 44 in BarraganSteven
# Processing Image - 45 in BarraganSteven
# Processing Image - 46 in BarraganSteven
# Processing Image - 47 in BarraganSteven
# Processing Image - 48 in BarraganSteven
# Processing Image - 49 in BarraganSteven
# Processing Image - 50 in BarraganSteven
# Processing Image - 51 in BarraganSteven
# Processing Image - 52 in BarraganSteven
# Processing Image - 53 in BarraganSteven
# Processing Image - 54 in BarraganSteven
# Processing Image - 55 in BarraganSteven
# Processing Image - 56 in BarraganSteven
# Processing Image - 57 in BarraganSteven
# Processing Image - 58 in BarraganSteven
# Processing Image - 59 in BarraganSteven
# Processing Image - 60 in BarraganSteven
# Processing Image - 61 in BarraganSteven
# Processing Image - 62 in BarraganSteven
# Processing Image - 63 in BarraganSteven
# Processing Image - 64 in BarraganSteven
# Processing Image - 65 in BarraganSteven
# Processing Image - 66 in BarraganSteven
# Processing Image - 67 in BarraganSteven
# Processing Image - 68 in BarraganSteven
# Processing Image - 69 in BarraganSteven
# Processing Image - 70 in BarraganSteven
# Processing Image - 71 in BarraganSteven
# Processing Image - 72 in BarraganSteven
# Processing Image - 73 in BarraganSteven
# Processing Image - 74 in BarraganSteven
# Processing Image - 75 in BarraganSteven
# Processing Image - 76 in BarraganSteven
# Processing Image - 77 in BarraganSteven
# Processing Image - 78 in BarraganSteven
# Processing Image - 79 in BarraganSteven
# Processing Image - 80 in BarraganSteven
# Processing Image - 81 in BarraganSteven
# Processing Image - 82 in BarraganSteven
# Processing Image - 83 in BarraganSteven
# Processing Image - 84 in BarraganSteven
# Processing Image - 85 in BarraganSteven
# Processing Image - 86 in BarraganSteven
# Processing Image - 87 in BarraganSteven
# Processing Image - 88 in BarraganSteven
# Processing Image - 89 in BarraganSteven
# Processing Image - 90 in BarraganSteven
# Processing Image - 91 in BarraganSteven
# Processing Image - 92 in BarraganSteven
# Processing Image - 93 in BarraganSteven
# Processing Image - 94 in BarraganSteven
# Processing Image - 95 in BarraganSteven
# Processing Image - 96 in BarraganSteven
# Processing Image - 97 in BarraganSteven
# Processing Image - 98 in BarraganSteven
# Processing Image - 99 in BarraganSteven
# Processing Image - 100 in BarraganSteven
# Processing Image - 101 in BarraganSteven
# Processing Image - 102 in BarraganSteven
# Processing Image - 103 in BarraganSteven
# Processing Image - 104 in BarraganSteven
# Processing Image - 105 in BarraganSteven
# Processing Image - 106 in BarraganSteven
# Processing Image - 107 in BarraganSteven
# Processing Image - 108 in BarraganSteven
# Processing Image - 109 in BarraganSteven
# Processing Image - 110 in BarraganSteven
# Processing Image - 111 in BarraganSteven
# Processing Image - 112 in BarraganSteven
# Processing Image - 113 in BarraganSteven
# Processing Image - 114 in BarraganSteven
# Processing Image - 115 in BarraganSteven
# Processing Image - 116 in BarraganSteven
# Processing Image - 117 in BarraganSteven
# Processing Image - 118 in BarraganSteven
# Processing Image - 119 in BarraganSteven
# Processing Image - 120 in BarraganSteven
# Processing Image - 121 in BarraganSteven
# Processing Image - 122 in BarraganSteven
# Processing Image - 123 in BarraganSteven
# Processing Image - 124 in BarraganSteven
# Processing Image - 125 in BarraganSteven
# Processing Image - 126 in BarraganSteven
# Processing Image - 127 in BarraganSteven
# Processing Image - 128 in BarraganSteven
# Processing Image - 129 in BarraganSteven
# Processing Image - 130 in BarraganSteven
# Processing Image - 131 in BarraganSteven
# Processing Image - 132 in BarraganSteven
# Processing Image - 133 in BarraganSteven
# Processing Image - 134 in BarraganSteven
# Processing Image - 135 in BarraganSteven
# Processing Image - 136 in BarraganSteven
# Processing Image - 137 in BarraganSteven
# Processing Image - 138 in BarraganSteven
# Processing Image - 139 in BarraganSteven
# Processing Image - 140 in BarraganSteven
# Processing Image - 1 in CevallosJoan
# Processing Image - 2 in CevallosJoan
# Processing Image - 3 in CevallosJoan
# Processing Image - 4 in CevallosJoan
# Processing Image - 5 in CevallosJoan
# Processing Image - 6 in CevallosJoan
# Processing Image - 7 in CevallosJoan
# Processing Image - 8 in CevallosJoan
# Processing Image - 9 in CevallosJoan
# Processing Image - 1 in EnriquezSelena
# Processing Image - 2 in EnriquezSelena
# Processing Image - 3 in EnriquezSelena
# Processing Image - 4 in EnriquezSelena
# Processing Image - 5 in EnriquezSelena
# Processing Image - 6 in EnriquezSelena
# Processing Image - 7 in EnriquezSelena
# Processing Image - 8 in EnriquezSelena
# Processing Image - 9 in EnriquezSelena
# Processing Image - 10 in EnriquezSelena
# Processing Image - 11 in EnriquezSelena
# Processing Image - 12 in EnriquezSelena
# Processing Image - 13 in EnriquezSelena
# Processing Image - 14 in EnriquezSelena
# Processing Image - 15 in EnriquezSelena
# Processing Image - 16 in EnriquezSelena
# Processing Image - 17 in EnriquezSelena
# Processing Image - 18 in EnriquezSelena
# Processing Image - 19 in EnriquezSelena
# Processing Image - 20 in EnriquezSelena
# Processing Image - 21 in EnriquezSelena
# Processing Image - 22 in EnriquezSelena
# Processing Image - 23 in EnriquezSelena
# Processing Image - 24 in EnriquezSelena
# Processing Image - 25 in EnriquezSelena
# Processing Image - 26 in EnriquezSelena
# Processing Image - 27 in EnriquezSelena
# Processing Image - 28 in EnriquezSelena
# Processing Image - 29 in EnriquezSelena
# Processing Image - 30 in EnriquezSelena
# Processing Image - 31 in EnriquezSelena
# Processing Image - 32 in EnriquezSelena
# Processing Image - 33 in EnriquezSelena
# Processing Image - 34 in EnriquezSelena
# Processing Image - 35 in EnriquezSelena
# Processing Image - 36 in EnriquezSelena
# Processing Image - 37 in EnriquezSelena
# Processing Image - 38 in EnriquezSelena
# Processing Image - 39 in EnriquezSelena
# Processing Image - 40 in EnriquezSelena
# Processing Image - 41 in EnriquezSelena
# Processing Image - 42 in EnriquezSelena
# Processing Image - 43 in EnriquezSelena
# Processing Image - 44 in EnriquezSelena
# Processing Image - 45 in EnriquezSelena
# Processing Image - 46 in EnriquezSelena
# Processing Image - 47 in EnriquezSelena
# Processing Image - 48 in EnriquezSelena
# Processing Image - 49 in EnriquezSelena
# Processing Image - 50 in EnriquezSelena
# Processing Image - 1 in GenesisHeredia
# Processing Image - 2 in GenesisHeredia
# Processing Image - 3 in GenesisHeredia
# Processing Image - 4 in GenesisHeredia
# Processing Image - 5 in GenesisHeredia
# Processing Image - 6 in GenesisHeredia
# Processing Image - 7 in GenesisHeredia
# Processing Image - 8 in GenesisHeredia
# Processing Image - 9 in GenesisHeredia
# Processing Image - 10 in GenesisHeredia
# Processing Image - 11 in GenesisHeredia
# Processing Image - 12 in GenesisHeredia
# Processing Image - 13 in GenesisHeredia
# Processing Image - 14 in GenesisHeredia
# Processing Image - 15 in GenesisHeredia
# Processing Image - 16 in GenesisHeredia
# Processing Image - 17 in GenesisHeredia
# Processing Image - 18 in GenesisHeredia
# Processing Image - 19 in GenesisHeredia
# Processing Image - 20 in GenesisHeredia
# Processing Image - 21 in GenesisHeredia
# Processing Image - 22 in GenesisHeredia
# Processing Image - 23 in GenesisHeredia
# Processing Image - 24 in GenesisHeredia
# Processing Image - 25 in GenesisHeredia
# Processing Image - 26 in GenesisHeredia
# Processing Image - 27 in GenesisHeredia
# Processing Image - 28 in GenesisHeredia
# Processing Image - 29 in GenesisHeredia
# Processing Image - 30 in GenesisHeredia
# Processing Image - 31 in GenesisHeredia
# Processing Image - 32 in GenesisHeredia
# Processing Image - 33 in GenesisHeredia
# Processing Image - 34 in GenesisHeredia
# Processing Image - 35 in GenesisHeredia
# Processing Image - 36 in GenesisHeredia
# Processing Image - 37 in GenesisHeredia
# Processing Image - 38 in GenesisHeredia
# Processing Image - 39 in GenesisHeredia
# Processing Image - 40 in GenesisHeredia
# Processing Image - 41 in GenesisHeredia
# Processing Image - 42 in GenesisHeredia
# Processing Image - 43 in GenesisHeredia
# Processing Image - 44 in GenesisHeredia
# Processing Image - 45 in GenesisHeredia
# Processing Image - 46 in GenesisHeredia
# Processing Image - 47 in GenesisHeredia
# Processing Image - 48 in GenesisHeredia
# Processing Image - 49 in GenesisHeredia
# Processing Image - 50 in GenesisHeredia
# Processing Image - 51 in GenesisHeredia
# Processing Image - 52 in GenesisHeredia
# Processing Image - 53 in GenesisHeredia
# Processing Image - 54 in GenesisHeredia
# Processing Image - 55 in GenesisHeredia
# Processing Image - 56 in GenesisHeredia
# Processing Image - 57 in GenesisHeredia
# Processing Image - 58 in GenesisHeredia
# Processing Image - 59 in GenesisHeredia
# Processing Image - 60 in GenesisHeredia
# Processing Image - 61 in GenesisHeredia
# Processing Image - 62 in GenesisHeredia
# Processing Image - 63 in GenesisHeredia
# Processing Image - 64 in GenesisHeredia
# Processing Image - 65 in GenesisHeredia
# Processing Image - 66 in GenesisHeredia
# Processing Image - 67 in GenesisHeredia
# Processing Image - 68 in GenesisHeredia
# Processing Image - 69 in GenesisHeredia
# Processing Image - 70 in GenesisHeredia
# Processing Image - 71 in GenesisHeredia
# Processing Image - 72 in GenesisHeredia
# Processing Image - 73 in GenesisHeredia
# Processing Image - 74 in GenesisHeredia
# Processing Image - 75 in GenesisHeredia
# Processing Image - 76 in GenesisHeredia
# Processing Image - 77 in GenesisHeredia
# Processing Image - 78 in GenesisHeredia
# Processing Image - 79 in GenesisHeredia
# Processing Image - 80 in GenesisHeredia
# Processing Image - 81 in GenesisHeredia
# Processing Image - 82 in GenesisHeredia
# Processing Image - 83 in GenesisHeredia
# Processing Image - 84 in GenesisHeredia
# Processing Image - 85 in GenesisHeredia
# Processing Image - 86 in GenesisHeredia
# Processing Image - 87 in GenesisHeredia
# Processing Image - 88 in GenesisHeredia
# Processing Image - 89 in GenesisHeredia
# Processing Image - 90 in GenesisHeredia
# Processing Image - 91 in GenesisHeredia
# Processing Image - 92 in GenesisHeredia
# Processing Image - 93 in GenesisHeredia
# Processing Image - 94 in GenesisHeredia
# Processing Image - 95 in GenesisHeredia
# Processing Image - 96 in GenesisHeredia
# Processing Image - 97 in GenesisHeredia
# Processing Image - 98 in GenesisHeredia
# Processing Image - 99 in GenesisHeredia
# Processing Image - 100 in GenesisHeredia
# Processing Image - 1 in GoyesAnthony
# Processing Image - 2 in GoyesAnthony
# Processing Image - 3 in GoyesAnthony
# Processing Image - 4 in GoyesAnthony
# Processing Image - 5 in GoyesAnthony
# Processing Image - 6 in GoyesAnthony
# Processing Image - 7 in GoyesAnthony
# Processing Image - 8 in GoyesAnthony
# Processing Image - 9 in GoyesAnthony
# Processing Image - 10 in GoyesAnthony
# Processing Image - 11 in GoyesAnthony
# Processing Image - 12 in GoyesAnthony
# Processing Image - 13 in GoyesAnthony
# Processing Image - 14 in GoyesAnthony
# Processing Image - 15 in GoyesAnthony
# Processing Image - 16 in GoyesAnthony
# Processing Image - 17 in GoyesAnthony
# Processing Image - 18 in GoyesAnthony
# Processing Image - 19 in GoyesAnthony
# Processing Image - 20 in GoyesAnthony
# Processing Image - 21 in GoyesAnthony
# Processing Image - 22 in GoyesAnthony
# Processing Image - 23 in GoyesAnthony
# Processing Image - 24 in GoyesAnthony
# Processing Image - 25 in GoyesAnthony
# Processing Image - 26 in GoyesAnthony
# Processing Image - 27 in GoyesAnthony
# Processing Image - 28 in GoyesAnthony
# Processing Image - 29 in GoyesAnthony
# Processing Image - 30 in GoyesAnthony
# Processing Image - 31 in GoyesAnthony
# Processing Image - 32 in GoyesAnthony
# Processing Image - 33 in GoyesAnthony
# Processing Image - 34 in GoyesAnthony
# Processing Image - 35 in GoyesAnthony
# Processing Image - 36 in GoyesAnthony
# Processing Image - 37 in GoyesAnthony
# Processing Image - 38 in GoyesAnthony
# Processing Image - 39 in GoyesAnthony
# Processing Image - 40 in GoyesAnthony
# Processing Image - 41 in GoyesAnthony
# Processing Image - 42 in GoyesAnthony
# Processing Image - 43 in GoyesAnthony
# Processing Image - 44 in GoyesAnthony
# Processing Image - 45 in GoyesAnthony
# Processing Image - 46 in GoyesAnthony
# Processing Image - 47 in GoyesAnthony
# Processing Image - 48 in GoyesAnthony
# Processing Image - 49 in GoyesAnthony
# Processing Image - 50 in GoyesAnthony
# Processing Image - 51 in GoyesAnthony
# Processing Image - 52 in GoyesAnthony
# Processing Image - 53 in GoyesAnthony
# Processing Image - 54 in GoyesAnthony
# Processing Image - 55 in GoyesAnthony
# Processing Image - 56 in GoyesAnthony
# Processing Image - 57 in GoyesAnthony
# Processing Image - 58 in GoyesAnthony
# Processing Image - 59 in GoyesAnthony
# Processing Image - 60 in GoyesAnthony
# Processing Image - 61 in GoyesAnthony
# Processing Image - 62 in GoyesAnthony
# Processing Image - 63 in GoyesAnthony
# Processing Image - 64 in GoyesAnthony
# Processing Image - 65 in GoyesAnthony
# Processing Image - 66 in GoyesAnthony
# Processing Image - 67 in GoyesAnthony
# Processing Image - 68 in GoyesAnthony
# Processing Image - 69 in GoyesAnthony
# Processing Image - 70 in GoyesAnthony
# Processing Image - 71 in GoyesAnthony
# Processing Image - 72 in GoyesAnthony
# Processing Image - 73 in GoyesAnthony
# Processing Image - 74 in GoyesAnthony
# Processing Image - 75 in GoyesAnthony
# Processing Image - 76 in GoyesAnthony
# Processing Image - 77 in GoyesAnthony
# Processing Image - 78 in GoyesAnthony
# Processing Image - 79 in GoyesAnthony
# Processing Image - 80 in GoyesAnthony
# Processing Image - 81 in GoyesAnthony
# Processing Image - 82 in GoyesAnthony
# Processing Image - 83 in GoyesAnthony
# Processing Image - 84 in GoyesAnthony
# Processing Image - 85 in GoyesAnthony
# Processing Image - 86 in GoyesAnthony
# Processing Image - 87 in GoyesAnthony
# Processing Image - 88 in GoyesAnthony
# Processing Image - 89 in GoyesAnthony
# Processing Image - 90 in GoyesAnthony
# Processing Image - 91 in GoyesAnthony
# Processing Image - 92 in GoyesAnthony
# Processing Image - 93 in GoyesAnthony
# Processing Image - 94 in GoyesAnthony
# Processing Image - 95 in GoyesAnthony
# Processing Image - 96 in GoyesAnthony
# Processing Image - 97 in GoyesAnthony
# Processing Image - 98 in GoyesAnthony
# Processing Image - 99 in GoyesAnthony
# Processing Image - 1 in Jhon Zambrano
# Processing Image - 2 in Jhon Zambrano
# Processing Image - 3 in Jhon Zambrano
# Processing Image - 4 in Jhon Zambrano
# Processing Image - 5 in Jhon Zambrano
# Processing Image - 6 in Jhon Zambrano
# Processing Image - 7 in Jhon Zambrano
# Processing Image - 8 in Jhon Zambrano
# Processing Image - 9 in Jhon Zambrano
# Processing Image - 10 in Jhon Zambrano
# Processing Image - 11 in Jhon Zambrano
# Processing Image - 12 in Jhon Zambrano
# Processing Image - 13 in Jhon Zambrano
# Processing Image - 14 in Jhon Zambrano
# Processing Image - 15 in Jhon Zambrano
# Processing Image - 16 in Jhon Zambrano
# Processing Image - 17 in Jhon Zambrano
# Processing Image - 18 in Jhon Zambrano
# Processing Image - 19 in Jhon Zambrano
# Processing Image - 20 in Jhon Zambrano
# Processing Image - 21 in Jhon Zambrano
# Processing Image - 22 in Jhon Zambrano
# Processing Image - 23 in Jhon Zambrano
# Processing Image - 24 in Jhon Zambrano
# Processing Image - 25 in Jhon Zambrano
# Processing Image - 26 in Jhon Zambrano
# Processing Image - 27 in Jhon Zambrano
# Processing Image - 28 in Jhon Zambrano
# Processing Image - 29 in Jhon Zambrano
# Processing Image - 30 in Jhon Zambrano
# Processing Image - 31 in Jhon Zambrano
# Processing Image - 32 in Jhon Zambrano
# Processing Image - 33 in Jhon Zambrano
# Processing Image - 34 in Jhon Zambrano
# Processing Image - 35 in Jhon Zambrano
# Processing Image - 36 in Jhon Zambrano
# Processing Image - 37 in Jhon Zambrano
# Processing Image - 38 in Jhon Zambrano
# Processing Image - 39 in Jhon Zambrano
# Processing Image - 40 in Jhon Zambrano
# Processing Image - 41 in Jhon Zambrano
# Processing Image - 42 in Jhon Zambrano
# Processing Image - 43 in Jhon Zambrano
# Processing Image - 44 in Jhon Zambrano
# Processing Image - 45 in Jhon Zambrano
# Processing Image - 46 in Jhon Zambrano
# Processing Image - 47 in Jhon Zambrano
# Processing Image - 48 in Jhon Zambrano
# Processing Image - 49 in Jhon Zambrano
# Processing Image - 50 in Jhon Zambrano
# Processing Image - 51 in Jhon Zambrano
# Processing Image - 52 in Jhon Zambrano
# Processing Image - 53 in Jhon Zambrano
# Processing Image - 54 in Jhon Zambrano
# Processing Image - 55 in Jhon Zambrano
# Processing Image - 56 in Jhon Zambrano
# Processing Image - 57 in Jhon Zambrano
# Processing Image - 58 in Jhon Zambrano
# Processing Image - 59 in Jhon Zambrano
# Processing Image - 60 in Jhon Zambrano
# Processing Image - 61 in Jhon Zambrano
# Processing Image - 62 in Jhon Zambrano
# Processing Image - 63 in Jhon Zambrano
# Processing Image - 64 in Jhon Zambrano
# Processing Image - 65 in Jhon Zambrano
# Processing Image - 66 in Jhon Zambrano
# Processing Image - 67 in Jhon Zambrano
# Processing Image - 68 in Jhon Zambrano
# Processing Image - 69 in Jhon Zambrano
# Processing Image - 70 in Jhon Zambrano
# Processing Image - 71 in Jhon Zambrano
# Processing Image - 72 in Jhon Zambrano
# Processing Image - 73 in Jhon Zambrano
# Processing Image - 74 in Jhon Zambrano
# Processing Image - 75 in Jhon Zambrano
# Processing Image - 76 in Jhon Zambrano
# Processing Image - 77 in Jhon Zambrano
# Processing Image - 78 in Jhon Zambrano
# Processing Image - 79 in Jhon Zambrano
# Processing Image - 80 in Jhon Zambrano
# Processing Image - 81 in Jhon Zambrano
# Processing Image - 82 in Jhon Zambrano
# Processing Image - 83 in Jhon Zambrano
# Processing Image - 84 in Jhon Zambrano
# Processing Image - 85 in Jhon Zambrano
# Processing Image - 86 in Jhon Zambrano
# Processing Image - 87 in Jhon Zambrano
# Processing Image - 88 in Jhon Zambrano
# Processing Image - 89 in Jhon Zambrano
# Processing Image - 90 in Jhon Zambrano
# Processing Image - 91 in Jhon Zambrano
# Processing Image - 92 in Jhon Zambrano
# Processing Image - 93 in Jhon Zambrano
# Processing Image - 94 in Jhon Zambrano
# Processing Image - 95 in Jhon Zambrano
# Processing Image - 96 in Jhon Zambrano
# Processing Image - 97 in Jhon Zambrano
# Processing Image - 98 in Jhon Zambrano
# Processing Image - 99 in Jhon Zambrano
# Processing Image - 100 in Jhon Zambrano
# Processing Image - 101 in Jhon Zambrano
# Processing Image - 102 in Jhon Zambrano
# Processing Image - 103 in Jhon Zambrano
# Processing Image - 104 in Jhon Zambrano
# Processing Image - 105 in Jhon Zambrano
# Processing Image - 106 in Jhon Zambrano
# Processing Image - 107 in Jhon Zambrano
# Processing Image - 108 in Jhon Zambrano
# Processing Image - 109 in Jhon Zambrano
# Processing Image - 110 in Jhon Zambrano
# Processing Image - 111 in Jhon Zambrano
# Processing Image - 112 in Jhon Zambrano
# Processing Image - 113 in Jhon Zambrano
# Processing Image - 114 in Jhon Zambrano
# Processing Image - 115 in Jhon Zambrano
# Processing Image - 116 in Jhon Zambrano
# Processing Image - 117 in Jhon Zambrano
# Processing Image - 118 in Jhon Zambrano
# Processing Image - 119 in Jhon Zambrano
# Processing Image - 120 in Jhon Zambrano
# Processing Image - 121 in Jhon Zambrano
# Processing Image - 122 in Jhon Zambrano
# Processing Image - 123 in Jhon Zambrano
# Processing Image - 124 in Jhon Zambrano
# Processing Image - 125 in Jhon Zambrano
# Processing Image - 126 in Jhon Zambrano
# Processing Image - 127 in Jhon Zambrano
# Processing Image - 128 in Jhon Zambrano
# Processing Image - 129 in Jhon Zambrano
# Processing Image - 130 in Jhon Zambrano
# Processing Image - 1 in Jordan Espinosa
# Processing Image - 2 in Jordan Espinosa
# Processing Image - 3 in Jordan Espinosa
# Processing Image - 4 in Jordan Espinosa
# Processing Image - 5 in Jordan Espinosa
# Processing Image - 6 in Jordan Espinosa
# Processing Image - 7 in Jordan Espinosa
# Processing Image - 8 in Jordan Espinosa
# Processing Image - 9 in Jordan Espinosa
# Processing Image - 10 in Jordan Espinosa
# Processing Image - 11 in Jordan Espinosa
# Processing Image - 12 in Jordan Espinosa
# Processing Image - 13 in Jordan Espinosa
# Processing Image - 14 in Jordan Espinosa
# Processing Image - 15 in Jordan Espinosa
# Processing Image - 16 in Jordan Espinosa
# Processing Image - 17 in Jordan Espinosa
# Processing Image - 18 in Jordan Espinosa
# Processing Image - 19 in Jordan Espinosa
# Processing Image - 20 in Jordan Espinosa
# Processing Image - 21 in Jordan Espinosa
# Processing Image - 22 in Jordan Espinosa
# Processing Image - 23 in Jordan Espinosa
# Processing Image - 24 in Jordan Espinosa
# Processing Image - 25 in Jordan Espinosa
# Processing Image - 26 in Jordan Espinosa
# Processing Image - 27 in Jordan Espinosa
# Processing Image - 28 in Jordan Espinosa
# Processing Image - 29 in Jordan Espinosa
# Processing Image - 30 in Jordan Espinosa
# Processing Image - 31 in Jordan Espinosa
# Processing Image - 32 in Jordan Espinosa
# Processing Image - 33 in Jordan Espinosa
# Processing Image - 34 in Jordan Espinosa
# Processing Image - 35 in Jordan Espinosa
# Processing Image - 36 in Jordan Espinosa
# Processing Image - 37 in Jordan Espinosa
# Processing Image - 38 in Jordan Espinosa
# Processing Image - 39 in Jordan Espinosa
# Processing Image - 40 in Jordan Espinosa
# Processing Image - 41 in Jordan Espinosa
# Processing Image - 42 in Jordan Espinosa
# Processing Image - 43 in Jordan Espinosa
# Processing Image - 44 in Jordan Espinosa
# Processing Image - 45 in Jordan Espinosa
# Processing Image - 46 in Jordan Espinosa
# Processing Image - 47 in Jordan Espinosa
# Processing Image - 48 in Jordan Espinosa
# Processing Image - 49 in Jordan Espinosa
# Processing Image - 50 in Jordan Espinosa
# Processing Image - 1 in Jorge Borrero
# Processing Image - 2 in Jorge Borrero
# Processing Image - 3 in Jorge Borrero
# Processing Image - 4 in Jorge Borrero
# Processing Image - 5 in Jorge Borrero
# Processing Image - 6 in Jorge Borrero
# Processing Image - 7 in Jorge Borrero
# Processing Image - 8 in Jorge Borrero
# Processing Image - 9 in Jorge Borrero
# Processing Image - 10 in Jorge Borrero
# Processing Image - 11 in Jorge Borrero
# Processing Image - 12 in Jorge Borrero
# Processing Image - 13 in Jorge Borrero
# Processing Image - 14 in Jorge Borrero
# Processing Image - 15 in Jorge Borrero
# Processing Image - 16 in Jorge Borrero
# Processing Image - 17 in Jorge Borrero
# Processing Image - 18 in Jorge Borrero
# Processing Image - 19 in Jorge Borrero
# Processing Image - 20 in Jorge Borrero
# Processing Image - 21 in Jorge Borrero
# Processing Image - 22 in Jorge Borrero
# Processing Image - 23 in Jorge Borrero
# Processing Image - 24 in Jorge Borrero
# Processing Image - 25 in Jorge Borrero
# Processing Image - 26 in Jorge Borrero
# Processing Image - 27 in Jorge Borrero
# Processing Image - 28 in Jorge Borrero
# Processing Image - 29 in Jorge Borrero
# Processing Image - 30 in Jorge Borrero
# Processing Image - 1 in JoseRuiz
# Processing Image - 2 in JoseRuiz
# Processing Image - 3 in JoseRuiz
# Processing Image - 4 in JoseRuiz
# Processing Image - 5 in JoseRuiz
# Processing Image - 6 in JoseRuiz
# Processing Image - 7 in JoseRuiz
# Processing Image - 8 in JoseRuiz
# Processing Image - 9 in JoseRuiz
# Processing Image - 10 in JoseRuiz
# Processing Image - 11 in JoseRuiz
# Processing Image - 12 in JoseRuiz
# Processing Image - 13 in JoseRuiz
# Processing Image - 14 in JoseRuiz
# Processing Image - 15 in JoseRuiz
# Processing Image - 16 in JoseRuiz
# Processing Image - 17 in JoseRuiz
# Processing Image - 18 in JoseRuiz
# Processing Image - 19 in JoseRuiz
# Processing Image - 20 in JoseRuiz
# Processing Image - 21 in JoseRuiz
# Processing Image - 22 in JoseRuiz
# Processing Image - 23 in JoseRuiz
# Processing Image - 24 in JoseRuiz
# Processing Image - 25 in JoseRuiz
# Processing Image - 26 in JoseRuiz
# Processing Image - 27 in JoseRuiz
# Processing Image - 28 in JoseRuiz
# Processing Image - 29 in JoseRuiz
# Processing Image - 30 in JoseRuiz
# Processing Image - 31 in JoseRuiz
# Processing Image - 32 in JoseRuiz
# Processing Image - 33 in JoseRuiz
# Processing Image - 34 in JoseRuiz
# Processing Image - 35 in JoseRuiz
# Processing Image - 36 in JoseRuiz
# Processing Image - 37 in JoseRuiz
# Processing Image - 38 in JoseRuiz
# Processing Image - 39 in JoseRuiz
# Processing Image - 40 in JoseRuiz
# Processing Image - 41 in JoseRuiz
# Processing Image - 42 in JoseRuiz
# Processing Image - 43 in JoseRuiz
# Processing Image - 44 in JoseRuiz
# Processing Image - 45 in JoseRuiz
# Processing Image - 46 in JoseRuiz
# Processing Image - 47 in JoseRuiz
# Processing Image - 48 in JoseRuiz
# Processing Image - 49 in JoseRuiz
# Processing Image - 50 in JoseRuiz
# Processing Image - 51 in JoseRuiz
# Processing Image - 52 in JoseRuiz
# Processing Image - 53 in JoseRuiz
# Processing Image - 54 in JoseRuiz
# Processing Image - 55 in JoseRuiz
# Processing Image - 56 in JoseRuiz
# Processing Image - 57 in JoseRuiz
# Processing Image - 58 in JoseRuiz
# Processing Image - 59 in JoseRuiz
# Processing Image - 60 in JoseRuiz
# Processing Image - 61 in JoseRuiz
# Processing Image - 62 in JoseRuiz
# Processing Image - 63 in JoseRuiz
# Processing Image - 64 in JoseRuiz
# Processing Image - 65 in JoseRuiz
# Processing Image - 66 in JoseRuiz
# Processing Image - 67 in JoseRuiz
# Processing Image - 68 in JoseRuiz
# Processing Image - 69 in JoseRuiz
# Processing Image - 70 in JoseRuiz
# Processing Image - 71 in JoseRuiz
# Processing Image - 72 in JoseRuiz
# Processing Image - 73 in JoseRuiz
# Processing Image - 74 in JoseRuiz
# Processing Image - 75 in JoseRuiz
# Processing Image - 76 in JoseRuiz
# Processing Image - 77 in JoseRuiz
# Processing Image - 78 in JoseRuiz
# Processing Image - 79 in JoseRuiz
# Processing Image - 80 in JoseRuiz
# Processing Image - 81 in JoseRuiz
# Processing Image - 82 in JoseRuiz
# Processing Image - 83 in JoseRuiz
# Processing Image - 84 in JoseRuiz
# Processing Image - 85 in JoseRuiz
# Processing Image - 86 in JoseRuiz
# Processing Image - 87 in JoseRuiz
# Processing Image - 88 in JoseRuiz
# Processing Image - 89 in JoseRuiz
# Processing Image - 90 in JoseRuiz
# Processing Image - 91 in JoseRuiz
# Processing Image - 92 in JoseRuiz
# Processing Image - 93 in JoseRuiz
# Processing Image - 94 in JoseRuiz
# Processing Image - 95 in JoseRuiz
# Processing Image - 96 in JoseRuiz
# Processing Image - 97 in JoseRuiz
# Processing Image - 98 in JoseRuiz
# Processing Image - 99 in JoseRuiz
# Processing Image - 100 in JoseRuiz
# Processing Image - 1 in LucioCarlos
# Processing Image - 2 in LucioCarlos
# Processing Image - 3 in LucioCarlos
# Processing Image - 4 in LucioCarlos
# Processing Image - 5 in LucioCarlos
# Processing Image - 6 in LucioCarlos
# Processing Image - 7 in LucioCarlos
# Processing Image - 8 in LucioCarlos
# Processing Image - 9 in LucioCarlos
# Processing Image - 10 in LucioCarlos
# Processing Image - 11 in LucioCarlos
# Processing Image - 12 in LucioCarlos
# Processing Image - 13 in LucioCarlos
# Processing Image - 14 in LucioCarlos
# Processing Image - 15 in LucioCarlos
# Processing Image - 16 in LucioCarlos
# Processing Image - 17 in LucioCarlos
# Processing Image - 18 in LucioCarlos
# Processing Image - 19 in LucioCarlos
# Processing Image - 20 in LucioCarlos
# Processing Image - 21 in LucioCarlos
# Processing Image - 22 in LucioCarlos
# Processing Image - 23 in LucioCarlos
# Processing Image - 24 in LucioCarlos
# Processing Image - 25 in LucioCarlos
# Processing Image - 26 in LucioCarlos
# Processing Image - 27 in LucioCarlos
# Processing Image - 28 in LucioCarlos
# Processing Image - 29 in LucioCarlos
# Processing Image - 30 in LucioCarlos
# Processing Image - 31 in LucioCarlos
# Processing Image - 32 in LucioCarlos
# Processing Image - 33 in LucioCarlos
# Processing Image - 34 in LucioCarlos
# Processing Image - 35 in LucioCarlos
# Processing Image - 36 in LucioCarlos
# Processing Image - 37 in LucioCarlos
# Processing Image - 38 in LucioCarlos
# Processing Image - 39 in LucioCarlos
# Processing Image - 40 in LucioCarlos
# Processing Image - 41 in LucioCarlos
# Processing Image - 42 in LucioCarlos
# Processing Image - 43 in LucioCarlos
# Processing Image - 44 in LucioCarlos
# Processing Image - 45 in LucioCarlos
# Processing Image - 46 in LucioCarlos
# Processing Image - 47 in LucioCarlos
# Processing Image - 48 in LucioCarlos
# Processing Image - 49 in LucioCarlos
# Processing Image - 50 in LucioCarlos
# Processing Image - 51 in LucioCarlos
# Processing Image - 52 in LucioCarlos
# Processing Image - 53 in LucioCarlos
# Processing Image - 54 in LucioCarlos
# Processing Image - 55 in LucioCarlos
# Processing Image - 56 in LucioCarlos
# Processing Image - 57 in LucioCarlos
# Processing Image - 58 in LucioCarlos
# Processing Image - 59 in LucioCarlos
# Processing Image - 60 in LucioCarlos
# Processing Image - 61 in LucioCarlos
# Processing Image - 62 in LucioCarlos
# Processing Image - 63 in LucioCarlos
# Processing Image - 64 in LucioCarlos
# Processing Image - 65 in LucioCarlos
# Processing Image - 66 in LucioCarlos
# Processing Image - 67 in LucioCarlos
# Processing Image - 68 in LucioCarlos
# Processing Image - 69 in LucioCarlos
# Processing Image - 70 in LucioCarlos
# Processing Image - 71 in LucioCarlos
# Processing Image - 72 in LucioCarlos
# Processing Image - 73 in LucioCarlos
# Processing Image - 74 in LucioCarlos
# Processing Image - 75 in LucioCarlos
# Processing Image - 76 in LucioCarlos
# Processing Image - 77 in LucioCarlos
# Processing Image - 78 in LucioCarlos
# Processing Image - 79 in LucioCarlos
# Processing Image - 80 in LucioCarlos
# Processing Image - 81 in LucioCarlos
# Processing Image - 82 in LucioCarlos
# Processing Image - 83 in LucioCarlos
# Processing Image - 84 in LucioCarlos
# Processing Image - 85 in LucioCarlos
# Processing Image - 86 in LucioCarlos
# Processing Image - 87 in LucioCarlos
# Processing Image - 88 in LucioCarlos
# Processing Image - 89 in LucioCarlos
# Processing Image - 90 in LucioCarlos
# Processing Image - 91 in LucioCarlos
# Processing Image - 92 in LucioCarlos
# Processing Image - 93 in LucioCarlos
# Processing Image - 94 in LucioCarlos
# Processing Image - 95 in LucioCarlos
# Processing Image - 96 in LucioCarlos
# Processing Image - 97 in LucioCarlos
# Processing Image - 98 in LucioCarlos
# Processing Image - 99 in LucioCarlos
# Processing Image - 100 in LucioCarlos
# Processing Image - 1 in MasacheFernando
# Processing Image - 2 in MasacheFernando
# Processing Image - 3 in MasacheFernando
# Processing Image - 4 in MasacheFernando
# Processing Image - 5 in MasacheFernando
# Processing Image - 6 in MasacheFernando
# Processing Image - 7 in MasacheFernando
# Processing Image - 8 in MasacheFernando
# Processing Image - 9 in MasacheFernando
# Processing Image - 10 in MasacheFernando
# Processing Image - 11 in MasacheFernando
# Processing Image - 12 in MasacheFernando
# Processing Image - 13 in MasacheFernando
# Processing Image - 14 in MasacheFernando
# Processing Image - 15 in MasacheFernando
# Processing Image - 16 in MasacheFernando
# Processing Image - 17 in MasacheFernando
# Processing Image - 18 in MasacheFernando
# Processing Image - 19 in MasacheFernando
# Processing Image - 20 in MasacheFernando
# Processing Image - 21 in MasacheFernando
# Processing Image - 22 in MasacheFernando
# Processing Image - 23 in MasacheFernando
# Processing Image - 24 in MasacheFernando
# Processing Image - 25 in MasacheFernando
# Processing Image - 26 in MasacheFernando
# Processing Image - 27 in MasacheFernando
# Processing Image - 28 in MasacheFernando
# Processing Image - 29 in MasacheFernando
# Processing Image - 30 in MasacheFernando
# Processing Image - 31 in MasacheFernando
# Processing Image - 32 in MasacheFernando
# Processing Image - 33 in MasacheFernando
# Processing Image - 34 in MasacheFernando
# Processing Image - 35 in MasacheFernando
# Processing Image - 36 in MasacheFernando
# Processing Image - 37 in MasacheFernando
# Processing Image - 38 in MasacheFernando
# Processing Image - 39 in MasacheFernando
# Processing Image - 40 in MasacheFernando
# Processing Image - 41 in MasacheFernando
# Processing Image - 42 in MasacheFernando
# Processing Image - 43 in MasacheFernando
# Processing Image - 44 in MasacheFernando
# Processing Image - 45 in MasacheFernando
# Processing Image - 46 in MasacheFernando
# Processing Image - 47 in MasacheFernando
# Processing Image - 48 in MasacheFernando
# Processing Image - 49 in MasacheFernando
# Processing Image - 50 in MasacheFernando
# Processing Image - 51 in MasacheFernando
# Processing Image - 52 in MasacheFernando
# Processing Image - 53 in MasacheFernando
# Processing Image - 54 in MasacheFernando
# Processing Image - 55 in MasacheFernando
# Processing Image - 56 in MasacheFernando
# Processing Image - 57 in MasacheFernando
# Processing Image - 58 in MasacheFernando
# Processing Image - 59 in MasacheFernando
# Processing Image - 60 in MasacheFernando
# Processing Image - 61 in MasacheFernando
# Processing Image - 62 in MasacheFernando
# Processing Image - 63 in MasacheFernando
# Processing Image - 64 in MasacheFernando
# Processing Image - 65 in MasacheFernando
# Processing Image - 66 in MasacheFernando
# Processing Image - 67 in MasacheFernando
# Processing Image - 68 in MasacheFernando
# Processing Image - 69 in MasacheFernando
# Processing Image - 70 in MasacheFernando
# Processing Image - 1 in MelanyLopez
# Processing Image - 2 in MelanyLopez
# Processing Image - 3 in MelanyLopez
# Processing Image - 4 in MelanyLopez
# Processing Image - 5 in MelanyLopez
# Processing Image - 6 in MelanyLopez
# Processing Image - 7 in MelanyLopez
# Processing Image - 8 in MelanyLopez
# Processing Image - 9 in MelanyLopez
# Processing Image - 10 in MelanyLopez
# Processing Image - 11 in MelanyLopez
# Processing Image - 12 in MelanyLopez
# Processing Image - 13 in MelanyLopez
# Processing Image - 14 in MelanyLopez
# Processing Image - 15 in MelanyLopez
# Processing Image - 16 in MelanyLopez
# Processing Image - 17 in MelanyLopez
# Processing Image - 18 in MelanyLopez
# Processing Image - 19 in MelanyLopez
# Processing Image - 20 in MelanyLopez
# Processing Image - 21 in MelanyLopez
# Processing Image - 22 in MelanyLopez
# Processing Image - 23 in MelanyLopez
# Processing Image - 24 in MelanyLopez
# Processing Image - 25 in MelanyLopez
# Processing Image - 26 in MelanyLopez
# Processing Image - 27 in MelanyLopez
# Processing Image - 28 in MelanyLopez
# Processing Image - 29 in MelanyLopez
# Processing Image - 30 in MelanyLopez
# Processing Image - 31 in MelanyLopez
# Processing Image - 32 in MelanyLopez
# Processing Image - 33 in MelanyLopez
# Processing Image - 34 in MelanyLopez
# Processing Image - 35 in MelanyLopez
# Processing Image - 36 in MelanyLopez
# Processing Image - 37 in MelanyLopez
# Processing Image - 38 in MelanyLopez
# Processing Image - 39 in MelanyLopez
# Processing Image - 40 in MelanyLopez
# Processing Image - 41 in MelanyLopez
# Processing Image - 42 in MelanyLopez
# Processing Image - 43 in MelanyLopez
# Processing Image - 44 in MelanyLopez
# Processing Image - 45 in MelanyLopez
# Processing Image - 46 in MelanyLopez
# Processing Image - 47 in MelanyLopez
# Processing Image - 48 in MelanyLopez
# Processing Image - 49 in MelanyLopez
# Processing Image - 50 in MelanyLopez
# Processing Image - 51 in MelanyLopez
# Processing Image - 52 in MelanyLopez
# Processing Image - 53 in MelanyLopez
# Processing Image - 54 in MelanyLopez
# Processing Image - 55 in MelanyLopez
# Processing Image - 56 in MelanyLopez
# Processing Image - 57 in MelanyLopez
# Processing Image - 58 in MelanyLopez
# Processing Image - 59 in MelanyLopez
# Processing Image - 60 in MelanyLopez
# Processing Image - 61 in MelanyLopez
# Processing Image - 62 in MelanyLopez
# Processing Image - 63 in MelanyLopez
# Processing Image - 64 in MelanyLopez
# Processing Image - 65 in MelanyLopez
# Processing Image - 66 in MelanyLopez
# Processing Image - 67 in MelanyLopez
# Processing Image - 68 in MelanyLopez
# Processing Image - 69 in MelanyLopez
# Processing Image - 70 in MelanyLopez
# Processing Image - 71 in MelanyLopez
# Processing Image - 72 in MelanyLopez
# Processing Image - 73 in MelanyLopez
# Processing Image - 74 in MelanyLopez
# Processing Image - 75 in MelanyLopez
# Processing Image - 76 in MelanyLopez
# Processing Image - 77 in MelanyLopez
# Processing Image - 78 in MelanyLopez
# Processing Image - 79 in MelanyLopez
# Processing Image - 80 in MelanyLopez
# Processing Image - 81 in MelanyLopez
# Processing Image - 82 in MelanyLopez
# Processing Image - 83 in MelanyLopez
# Processing Image - 84 in MelanyLopez
# Processing Image - 85 in MelanyLopez
# Processing Image - 86 in MelanyLopez
# Processing Image - 87 in MelanyLopez
# Processing Image - 88 in MelanyLopez
# Processing Image - 89 in MelanyLopez
# Processing Image - 90 in MelanyLopez
# Processing Image - 91 in MelanyLopez
# Processing Image - 92 in MelanyLopez
# Processing Image - 93 in MelanyLopez
# Processing Image - 94 in MelanyLopez
# Processing Image - 95 in MelanyLopez
# Processing Image - 96 in MelanyLopez
# Processing Image - 97 in MelanyLopez
# Processing Image - 98 in MelanyLopez
# Processing Image - 99 in MelanyLopez
# Processing Image - 100 in MelanyLopez
# Processing Image - 101 in MelanyLopez
# Processing Image - 102 in MelanyLopez
# Processing Image - 103 in MelanyLopez
# Processing Image - 104 in MelanyLopez
# Processing Image - 105 in MelanyLopez
# Processing Image - 106 in MelanyLopez
# Processing Image - 107 in MelanyLopez
# Processing Image - 108 in MelanyLopez
# Processing Image - 109 in MelanyLopez
# Processing Image - 110 in MelanyLopez
# Processing Image - 1 in MosqueraLucy
# Processing Image - 2 in MosqueraLucy
# Processing Image - 3 in MosqueraLucy
# Processing Image - 4 in MosqueraLucy
# Processing Image - 5 in MosqueraLucy
# Processing Image - 6 in MosqueraLucy
# Processing Image - 7 in MosqueraLucy
# Processing Image - 8 in MosqueraLucy
# Processing Image - 9 in MosqueraLucy
# Processing Image - 10 in MosqueraLucy
# Processing Image - 11 in MosqueraLucy
# Processing Image - 12 in MosqueraLucy
# Processing Image - 13 in MosqueraLucy
# Processing Image - 14 in MosqueraLucy
# Processing Image - 15 in MosqueraLucy
# Processing Image - 16 in MosqueraLucy
# Processing Image - 17 in MosqueraLucy
# Processing Image - 18 in MosqueraLucy
# Processing Image - 19 in MosqueraLucy
# Processing Image - 20 in MosqueraLucy
# Processing Image - 21 in MosqueraLucy
# Processing Image - 22 in MosqueraLucy
# Processing Image - 23 in MosqueraLucy
# Processing Image - 24 in MosqueraLucy
# Processing Image - 25 in MosqueraLucy
# Processing Image - 26 in MosqueraLucy
# Processing Image - 27 in MosqueraLucy
# Processing Image - 28 in MosqueraLucy
# Processing Image - 29 in MosqueraLucy
# Processing Image - 30 in MosqueraLucy
# Processing Image - 31 in MosqueraLucy
# Processing Image - 32 in MosqueraLucy
# Processing Image - 33 in MosqueraLucy
# Processing Image - 34 in MosqueraLucy
# Processing Image - 35 in MosqueraLucy
# Processing Image - 36 in MosqueraLucy
# Processing Image - 37 in MosqueraLucy
# Processing Image - 38 in MosqueraLucy
# Processing Image - 39 in MosqueraLucy
# Processing Image - 40 in MosqueraLucy
# Processing Image - 41 in MosqueraLucy
# Processing Image - 42 in MosqueraLucy
# Processing Image - 43 in MosqueraLucy
# Processing Image - 44 in MosqueraLucy
# Processing Image - 45 in MosqueraLucy
# Processing Image - 46 in MosqueraLucy
# Processing Image - 47 in MosqueraLucy
# Processing Image - 48 in MosqueraLucy
# Processing Image - 49 in MosqueraLucy
# Processing Image - 50 in MosqueraLucy
# Processing Image - 51 in MosqueraLucy
# Processing Image - 52 in MosqueraLucy
# Processing Image - 53 in MosqueraLucy
# Processing Image - 54 in MosqueraLucy
# Processing Image - 55 in MosqueraLucy
# Processing Image - 56 in MosqueraLucy
# Processing Image - 57 in MosqueraLucy
# Processing Image - 58 in MosqueraLucy
# Processing Image - 59 in MosqueraLucy
# Processing Image - 60 in MosqueraLucy
# Processing Image - 61 in MosqueraLucy
# Processing Image - 62 in MosqueraLucy
# Processing Image - 63 in MosqueraLucy
# Processing Image - 64 in MosqueraLucy
# Processing Image - 65 in MosqueraLucy
# Processing Image - 66 in MosqueraLucy
# Processing Image - 67 in MosqueraLucy
# Processing Image - 68 in MosqueraLucy
# Processing Image - 69 in MosqueraLucy
# Processing Image - 70 in MosqueraLucy
# Processing Image - 71 in MosqueraLucy
# Processing Image - 72 in MosqueraLucy
# Processing Image - 73 in MosqueraLucy
# Processing Image - 74 in MosqueraLucy
# Processing Image - 75 in MosqueraLucy
# Processing Image - 76 in MosqueraLucy
# Processing Image - 77 in MosqueraLucy
# Processing Image - 78 in MosqueraLucy
# Processing Image - 79 in MosqueraLucy
# Processing Image - 80 in MosqueraLucy
# Processing Image - 81 in MosqueraLucy
# Processing Image - 82 in MosqueraLucy
# Processing Image - 83 in MosqueraLucy
# Processing Image - 84 in MosqueraLucy
# Processing Image - 85 in MosqueraLucy
# Processing Image - 86 in MosqueraLucy
# Processing Image - 87 in MosqueraLucy
# Processing Image - 88 in MosqueraLucy
# Processing Image - 89 in MosqueraLucy
# Processing Image - 90 in MosqueraLucy
# Processing Image - 91 in MosqueraLucy
# Processing Image - 92 in MosqueraLucy
# Processing Image - 93 in MosqueraLucy
# Processing Image - 94 in MosqueraLucy
# Processing Image - 95 in MosqueraLucy
# Processing Image - 96 in MosqueraLucy
# Processing Image - 97 in MosqueraLucy
# Processing Image - 98 in MosqueraLucy
# Processing Image - 99 in MosqueraLucy
# Processing Image - 100 in MosqueraLucy
# Processing Image - 101 in MosqueraLucy
# Processing Image - 102 in MosqueraLucy
# Processing Image - 103 in MosqueraLucy
# Processing Image - 104 in MosqueraLucy
# Processing Image - 105 in MosqueraLucy
# Processing Image - 106 in MosqueraLucy
# ...
# Processing Image - 357 in MosqueraLucy
# Processing Image - 358 in MosqueraLucy
# Processing Image - 359 in MosqueraLucy
# Processing Image - 360 in MosqueraLucy
# Processing Image - 361 in MosqueraLucy
# Processing Image - 362 in MosqueraLucy
# Processing Image - 363 in MosqueraLucy
# Processing Image - 364 in MosqueraLucy
# Processing Image - 365 in MosqueraLucy
# Processing Image - 366 in MosqueraLucy
# Processing Image - 367 in MosqueraLucy
# Processing Image - 368 in MosqueraLucy
# Processing Image - 369 in MosqueraLucy
# Processing Image - 370 in MosqueraLucy
# Processing Image - 371 in MosqueraLucy
# Processing Image - 372 in MosqueraLucy
# Processing Image - 373 in MosqueraLucy
# Processing Image - 374 in MosqueraLucy
# Processing Image - 375 in MosqueraLucy
# Processing Image - 376 in MosqueraLucy
# Processing Image - 377 in MosqueraLucy
# Processing Image - 378 in MosqueraLucy
# Processing Image - 379 in MosqueraLucy
# Processing Image - 380 in MosqueraLucy
# Processing Image - 381 in MosqueraLucy
# Processing Image - 382 in MosqueraLucy
# Processing Image - 383 in MosqueraLucy
# Processing Image - 384 in MosqueraLucy
# Processing Image - 385 in MosqueraLucy
# Processing Image - 386 in MosqueraLucy
# Processing Image - 387 in MosqueraLucy
# Processing Image - 388 in MosqueraLucy
# Processing Image - 389 in MosqueraLucy
# Processing Image - 390 in MosqueraLucy
# Processing Image - 391 in MosqueraLucy
# Processing Image - 392 in MosqueraLucy
# Processing Image - 393 in MosqueraLucy
# Processing Image - 394 in MosqueraLucy
# Processing Image - 395 in MosqueraLucy
# Processing Image - 396 in MosqueraLucy
# Processing Image - 397 in MosqueraLucy
# Processing Image - 398 in MosqueraLucy
# Processing Image - 399 in MosqueraLucy
# Processing Image - 400 in MosqueraLucy
# Processing Image - 401 in MosqueraLucy
# Processing Image - 402 in MosqueraLucy
# Processing Image - 403 in MosqueraLucy
# Processing Image - 404 in MosqueraLucy
# Processing Image - 405 in MosqueraLucy
# Processing Image - 406 in MosqueraLucy
# Processing Image - 407 in MosqueraLucy
# Processing Image - 408 in MosqueraLucy
# Processing Image - 409 in MosqueraLucy
# Processing Image - 410 in MosqueraLucy
# Processing Image - 411 in MosqueraLucy
# Processing Image - 412 in MosqueraLucy
# Processing Image - 413 in MosqueraLucy
# Processing Image - 414 in MosqueraLucy
# Processing Image - 415 in MosqueraLucy
# Processing Image - 416 in MosqueraLucy
# Processing Image - 417 in MosqueraLucy
# Processing Image - 418 in MosqueraLucy
# Processing Image - 419 in MosqueraLucy
# Processing Image - 420 in MosqueraLucy
# Processing Image - 421 in MosqueraLucy
# Processing Image - 422 in MosqueraLucy
# Processing Image - 423 in MosqueraLucy
# Processing Image - 424 in MosqueraLucy
# Processing Image - 425 in MosqueraLucy
# Processing Image - 426 in MosqueraLucy
# Processing Image - 427 in MosqueraLucy
# Processing Image - 428 in MosqueraLucy
# Processing Image - 429 in MosqueraLucy
# Processing Image - 430 in MosqueraLucy
# Processing Image - 431 in MosqueraLucy
# Processing Image - 432 in MosqueraLucy
# Processing Image - 433 in MosqueraLucy
# Processing Image - 434 in MosqueraLucy
# Processing Image - 435 in MosqueraLucy
# Processing Image - 436 in MosqueraLucy
# Processing Image - 437 in MosqueraLucy
# Processing Image - 438 in MosqueraLucy
# Processing Image - 439 in MosqueraLucy
# Processing Image - 440 in MosqueraLucy
# Processing Image - 441 in MosqueraLucy
# Processing Image - 442 in MosqueraLucy
# Processing Image - 443 in MosqueraLucy
# Processing Image - 444 in MosqueraLucy
# Processing Image - 445 in MosqueraLucy
# Processing Image - 446 in MosqueraLucy
# Processing Image - 447 in MosqueraLucy
# Processing Image - 448 in MosqueraLucy
# Processing Image - 449 in MosqueraLucy
# Processing Image - 450 in MosqueraLucy
# Processing Image - 451 in MosqueraLucy
# Processing Image - 452 in MosqueraLucy
# Processing Image - 453 in MosqueraLucy
# Processing Image - 454 in MosqueraLucy
# Processing Image - 455 in MosqueraLucy
# Processing Image - 456 in MosqueraLucy
# Processing Image - 457 in MosqueraLucy
# Processing Image - 458 in MosqueraLucy
# Processing Image - 459 in MosqueraLucy
# Processing Image - 460 in MosqueraLucy
# Processing Image - 461 in MosqueraLucy
# Processing Image - 462 in MosqueraLucy
# Processing Image - 463 in MosqueraLucy
# Processing Image - 464 in MosqueraLucy
# Processing Image - 465 in MosqueraLucy
# Processing Image - 466 in MosqueraLucy
# Processing Image - 467 in MosqueraLucy
# Processing Image - 468 in MosqueraLucy
# Processing Image - 469 in MosqueraLucy
# Processing Image - 470 in MosqueraLucy
# Processing Image - 471 in MosqueraLucy
# Processing Image - 472 in MosqueraLucy
# Processing Image - 473 in MosqueraLucy
# Processing Image - 474 in MosqueraLucy
# Processing Image - 475 in MosqueraLucy
# Processing Image - 476 in MosqueraLucy
# Processing Image - 477 in MosqueraLucy
# Processing Image - 478 in MosqueraLucy
# Processing Image - 479 in MosqueraLucy
# Processing Image - 480 in MosqueraLucy
# Processing Image - 481 in MosqueraLucy
# Processing Image - 482 in MosqueraLucy
# Processing Image - 483 in MosqueraLucy
# Processing Image - 484 in MosqueraLucy
# Processing Image - 485 in MosqueraLucy
# Processing Image - 486 in MosqueraLucy
# Processing Image - 487 in MosqueraLucy
# Processing Image - 488 in MosqueraLucy
# Processing Image - 489 in MosqueraLucy
# Processing Image - 490 in MosqueraLucy
# Processing Image - 491 in MosqueraLucy
# Processing Image - 492 in MosqueraLucy
# Processing Image - 493 in MosqueraLucy
# Processing Image - 494 in MosqueraLucy
# Processing Image - 495 in MosqueraLucy
# Processing Image - 496 in MosqueraLucy
# Processing Image - 497 in MosqueraLucy
# Processing Image - 498 in MosqueraLucy
# Processing Image - 499 in MosqueraLucy
# Processing Image - 500 in MosqueraLucy
# Processing Image - 501 in MosqueraLucy
# Processing Image - 502 in MosqueraLucy
# Processing Image - 503 in MosqueraLucy
# Processing Image - 504 in MosqueraLucy
# Processing Image - 505 in MosqueraLucy
# Processing Image - 506 in MosqueraLucy
# Processing Image - 507 in MosqueraLucy
# Processing Image - 508 in MosqueraLucy
# Processing Image - 509 in MosqueraLucy
# Processing Image - 510 in MosqueraLucy
# Processing Image - 511 in MosqueraLucy
# Processing Image - 512 in MosqueraLucy
# Processing Image - 513 in MosqueraLucy
# Processing Image - 514 in MosqueraLucy
# Processing Image - 515 in MosqueraLucy
# Processing Image - 516 in MosqueraLucy
# Processing Image - 517 in MosqueraLucy
# Processing Image - 518 in MosqueraLucy
# Processing Image - 519 in MosqueraLucy
# Processing Image - 520 in MosqueraLucy
# Processing Image - 521 in MosqueraLucy
# Processing Image - 522 in MosqueraLucy
# Processing Image - 523 in MosqueraLucy
# Processing Image - 524 in MosqueraLucy
# Processing Image - 525 in MosqueraLucy
# Processing Image - 526 in MosqueraLucy
# Processing Image - 527 in MosqueraLucy
# Processing Image - 528 in MosqueraLucy
# Processing Image - 529 in MosqueraLucy
# Processing Image - 530 in MosqueraLucy
# Processing Image - 531 in MosqueraLucy
# Processing Image - 532 in MosqueraLucy
# Processing Image - 533 in MosqueraLucy
# Processing Image - 534 in MosqueraLucy
# Processing Image - 535 in MosqueraLucy
# Processing Image - 536 in MosqueraLucy
# Processing Image - 537 in MosqueraLucy
# Processing Image - 538 in MosqueraLucy
# Processing Image - 539 in MosqueraLucy
# Processing Image - 540 in MosqueraLucy
# Processing Image - 541 in MosqueraLucy
# Processing Image - 542 in MosqueraLucy
# Processing Image - 543 in MosqueraLucy
# Processing Image - 544 in MosqueraLucy
# Processing Image - 545 in MosqueraLucy
# Processing Image - 546 in MosqueraLucy
# Processing Image - 547 in MosqueraLucy
# Processing Image - 548 in MosqueraLucy
# Processing Image - 549 in MosqueraLucy
# Processing Image - 550 in MosqueraLucy
# Processing Image - 551 in MosqueraLucy
# Processing Image - 552 in MosqueraLucy
# Processing Image - 553 in MosqueraLucy
# Processing Image - 554 in MosqueraLucy
# Processing Image - 555 in MosqueraLucy
# Processing Image - 556 in MosqueraLucy
# Processing Image - 557 in MosqueraLucy
# Processing Image - 558 in MosqueraLucy
# Processing Image - 559 in MosqueraLucy
# Processing Image - 560 in MosqueraLucy
# Processing Image - 561 in MosqueraLucy
# Processing Image - 562 in MosqueraLucy
# Processing Image - 563 in MosqueraLucy
# Processing Image - 564 in MosqueraLucy
# Processing Image - 565 in MosqueraLucy
# Processing Image - 566 in MosqueraLucy
# Processing Image - 567 in MosqueraLucy
# Processing Image - 568 in MosqueraLucy
# Processing Image - 569 in MosqueraLucy
# Processing Image - 570 in MosqueraLucy
# Processing Image - 571 in MosqueraLucy
# Processing Image - 572 in MosqueraLucy
# Processing Image - 573 in MosqueraLucy
# Processing Image - 574 in MosqueraLucy
# Processing Image - 575 in MosqueraLucy
# Processing Image - 576 in MosqueraLucy
# Processing Image - 577 in MosqueraLucy
# Processing Image - 578 in MosqueraLucy
# Processing Image - 579 in MosqueraLucy
# Processing Image - 580 in MosqueraLucy
# Processing Image - 581 in MosqueraLucy
# Processing Image - 582 in MosqueraLucy
# Processing Image - 583 in MosqueraLucy
# Processing Image - 584 in MosqueraLucy
# Processing Image - 585 in MosqueraLucy
# Processing Image - 586 in MosqueraLucy
# Processing Image - 587 in MosqueraLucy
# Processing Image - 588 in MosqueraLucy
# Processing Image - 589 in MosqueraLucy
# Processing Image - 590 in MosqueraLucy
# Processing Image - 591 in MosqueraLucy
# Processing Image - 592 in MosqueraLucy
# Processing Image - 593 in MosqueraLucy
# Processing Image - 594 in MosqueraLucy
# Processing Image - 595 in MosqueraLucy
# Processing Image - 596 in MosqueraLucy
# Processing Image - 597 in MosqueraLucy
# Processing Image - 598 in MosqueraLucy
# Processing Image - 599 in MosqueraLucy
# Processing Image - 600 in MosqueraLucy
# Processing Image - 601 in MosqueraLucy
# Processing Image - 602 in MosqueraLucy
# Processing Image - 603 in MosqueraLucy
# Processing Image - 604 in MosqueraLucy
# Processing Image - 605 in MosqueraLucy
# Processing Image - 606 in MosqueraLucy
# Processing Image - 607 in MosqueraLucy
# Processing Image - 608 in MosqueraLucy
# Processing Image - 609 in MosqueraLucy
# Processing Image - 610 in MosqueraLucy
# Processing Image - 611 in MosqueraLucy
# Processing Image - 612 in MosqueraLucy
# Processing Image - 613 in MosqueraLucy
# Processing Image - 614 in MosqueraLucy
# Processing Image - 615 in MosqueraLucy
# Processing Image - 616 in MosqueraLucy
# Processing Image - 617 in MosqueraLucy
# Processing Image - 618 in MosqueraLucy
# Processing Image - 619 in MosqueraLucy
# Processing Image - 620 in MosqueraLucy
# Processing Image - 621 in MosqueraLucy
# Processing Image - 622 in MosqueraLucy
# Processing Image - 623 in MosqueraLucy
# Processing Image - 624 in MosqueraLucy
# Processing Image - 625 in MosqueraLucy
# Processing Image - 626 in MosqueraLucy
# Processing Image - 627 in MosqueraLucy
# Processing Image - 628 in MosqueraLucy
# Processing Image - 629 in MosqueraLucy
# Processing Image - 630 in MosqueraLucy
# Processing Image - 631 in MosqueraLucy
# Processing Image - 632 in MosqueraLucy
# Processing Image - 633 in MosqueraLucy
# Processing Image - 634 in MosqueraLucy
# Processing Image - 635 in MosqueraLucy
# Processing Image - 636 in MosqueraLucy
# Processing Image - 637 in MosqueraLucy
# Processing Image - 638 in MosqueraLucy
# Processing Image - 639 in MosqueraLucy
# Processing Image - 640 in MosqueraLucy
# Processing Image - 641 in MosqueraLucy
# Processing Image - 642 in MosqueraLucy
# Processing Image - 643 in MosqueraLucy
# Processing Image - 644 in MosqueraLucy
# Processing Image - 645 in MosqueraLucy
# Processing Image - 646 in MosqueraLucy
# Processing Image - 647 in MosqueraLucy
# Processing Image - 648 in MosqueraLucy
# Processing Image - 649 in MosqueraLucy
# Processing Image - 650 in MosqueraLucy
# Processing Image - 651 in MosqueraLucy
# Processing Image - 652 in MosqueraLucy
# Processing Image - 653 in MosqueraLucy
# Processing Image - 654 in MosqueraLucy
# Processing Image - 655 in MosqueraLucy
# Processing Image - 656 in MosqueraLucy
# Processing Image - 657 in MosqueraLucy
# Processing Image - 658 in MosqueraLucy
# Processing Image - 659 in MosqueraLucy
# Processing Image - 660 in MosqueraLucy
# Processing Image - 661 in MosqueraLucy
# Processing Image - 662 in MosqueraLucy
# Processing Image - 663 in MosqueraLucy
# Processing Image - 664 in MosqueraLucy
# Processing Image - 665 in MosqueraLucy
# Processing Image - 666 in MosqueraLucy
# Processing Image - 667 in MosqueraLucy
# Processing Image - 668 in MosqueraLucy
# Processing Image - 669 in MosqueraLucy
# Processing Image - 670 in MosqueraLucy
# Processing Image - 671 in MosqueraLucy
# Processing Image - 672 in MosqueraLucy
# Processing Image - 673 in MosqueraLucy
# Processing Image - 674 in MosqueraLucy
# Processing Image - 675 in MosqueraLucy
# Processing Image - 676 in MosqueraLucy
# Processing Image - 677 in MosqueraLucy
# Processing Image - 678 in MosqueraLucy
# Processing Image - 679 in MosqueraLucy
# Processing Image - 680 in MosqueraLucy
# Processing Image - 681 in MosqueraLucy
# Processing Image - 682 in MosqueraLucy
# Processing Image - 683 in MosqueraLucy
# Processing Image - 684 in MosqueraLucy
# Processing Image - 685 in MosqueraLucy
# Processing Image - 686 in MosqueraLucy
# Processing Image - 687 in MosqueraLucy
# Processing Image - 688 in MosqueraLucy
# Processing Image - 689 in MosqueraLucy
# Processing Image - 690 in MosqueraLucy
# Processing Image - 691 in MosqueraLucy
# Processing Image - 692 in MosqueraLucy
# Processing Image - 693 in MosqueraLucy
# Processing Image - 694 in MosqueraLucy
# Processing Image - 695 in MosqueraLucy
# Processing Image - 696 in MosqueraLucy
# Processing Image - 697 in MosqueraLucy
# Processing Image - 698 in MosqueraLucy
# Processing Image - 699 in MosqueraLucy
# Processing Image - 700 in MosqueraLucy
# Processing Image - 701 in MosqueraLucy
# Processing Image - 702 in MosqueraLucy
# Processing Image - 703 in MosqueraLucy
# Processing Image - 704 in MosqueraLucy
# Processing Image - 705 in MosqueraLucy
# Processing Image - 706 in MosqueraLucy
# Processing Image - 707 in MosqueraLucy
# Processing Image - 708 in MosqueraLucy
# Processing Image - 709 in MosqueraLucy
# Processing Image - 710 in MosqueraLucy
# Processing Image - 711 in MosqueraLucy
# Processing Image - 712 in MosqueraLucy
# Processing Image - 713 in MosqueraLucy
# Processing Image - 714 in MosqueraLucy
# Processing Image - 715 in MosqueraLucy
# Processing Image - 716 in MosqueraLucy
# Processing Image - 717 in MosqueraLucy
# Processing Image - 718 in MosqueraLucy
# Processing Image - 719 in MosqueraLucy
# Processing Image - 720 in MosqueraLucy
# Processing Image - 721 in MosqueraLucy
# Processing Image - 722 in MosqueraLucy
# Processing Image - 723 in MosqueraLucy
# Processing Image - 724 in MosqueraLucy
# Processing Image - 725 in MosqueraLucy
# Processing Image - 726 in MosqueraLucy
# Processing Image - 727 in MosqueraLucy
# Processing Image - 728 in MosqueraLucy
# Processing Image - 729 in MosqueraLucy
# Processing Image - 730 in MosqueraLucy
# Processing Image - 731 in MosqueraLucy
# Processing Image - 732 in MosqueraLucy
# Processing Image - 733 in MosqueraLucy
# Processing Image - 734 in MosqueraLucy
# Processing Image - 735 in MosqueraLucy
# Processing Image - 736 in MosqueraLucy
# Processing Image - 737 in MosqueraLucy
# Processing Image - 738 in MosqueraLucy
# Processing Image - 739 in MosqueraLucy
# Processing Image - 740 in MosqueraLucy
# Processing Image - 741 in MosqueraLucy
# Processing Image - 742 in MosqueraLucy
# Processing Image - 743 in MosqueraLucy
# Processing Image - 744 in MosqueraLucy
# Processing Image - 745 in MosqueraLucy
# Processing Image - 746 in MosqueraLucy
# Processing Image - 747 in MosqueraLucy
# Processing Image - 748 in MosqueraLucy
# Processing Image - 749 in MosqueraLucy
# Processing Image - 750 in MosqueraLucy
# Processing Image - 751 in MosqueraLucy
# Processing Image - 752 in MosqueraLucy
# Processing Image - 753 in MosqueraLucy
# Processing Image - 754 in MosqueraLucy
# Processing Image - 755 in MosqueraLucy
# Processing Image - 756 in MosqueraLucy
# Processing Image - 757 in MosqueraLucy
# Processing Image - 758 in MosqueraLucy
# Processing Image - 759 in MosqueraLucy
# Processing Image - 760 in MosqueraLucy
# Processing Image - 761 in MosqueraLucy
# Processing Image - 762 in MosqueraLucy
# Processing Image - 763 in MosqueraLucy
# Processing Image - 764 in MosqueraLucy
# Processing Image - 765 in MosqueraLucy
# Processing Image - 766 in MosqueraLucy

# %% [markdown]
# ## Carga y exploracion de datos

# %%
""" Empezamos a trabajar con as imagenes ya procesadas anteriormente,por cada persona tenemos 5 clases. """

fpath = './PROYECTOrgb'
random_seed = 9

categories = os.listdir(fpath)
print("List of categories = ",categories,"\n\nNo. of categories = ", len(categories))
# Out:
# List of categories =  ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MasacheFernando', 'MelanyLopez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMaria', 'PauteKevin', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']
#
# No. of categories =  24

# %% [markdown]
# Para este paso procedemos a definir las categorias, los estudisntes elegidos tienen cada una de sus fotos almacenados en carpetas. Por ello a las imagenes anterirmente procesadas y eliminadas el fondo seras con las que trabajamos. Para cada uno selecionamos una categoria que va a ser identificada medinte el nombre de cada uno.

# %%
""" Se agrega etiquetas para cada una de las categorias ya especificadas anteriormente, con un total de 
153 etiquetas sumando todas las clases"""

#Se agrega etiquetas para cada una de las categorias ya especificadas anteriormente
def load_images_and_labels(categories):
    img_lst=[]
    labels=[]
    for index, category in enumerate(categories):
        for image_name in os.listdir(fpath+"/"+category):
            img = cv2.imread(fpath+"/"+category+"/"+image_name)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            img_array = Image.fromarray(img, 'RGB')
            
            img_lst.append(np.array(img_array))
            
            labels.append(index)
    return img_lst, labels

images, labels = load_images_and_labels(categories)
print("No. of images loaded = ",len(images),"\nNo. of labels loaded = ",len(labels))
print(type(images),type(labels))
# Out:
# No. of images loaded =  2729
# No. of labels loaded =  2729
# <class 'list'> <class 'list'>

# %%
images = np.array(images)
labels = np.array(labels)

print("Images shape = ",images.shape,"\nLabels shape = ",labels.shape)
print(type(images),type(labels))
# Out:
# Images shape =  (2729,)
# Labels shape =  (2729,)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# C:\Users\johan\AppData\Local\Temp\ipykernel_10408\464512149.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   images = np.array(images)

# %%
"""Mediante un plot extraemos imagenes aleatorias y las etiquetamos como imagen proyecto y el numero identificador"""
def display_rand_images(images, labels):

    plt.figure(1 , figsize = (19 , 10))
    n = 0 
    for i in range(9):
        n += 1 
        r = np.random.randint(0 , images.shape[0] , 1)
        
        plt.subplot(3 , 3 , n)
        plt.subplots_adjust(hspace = 0.3 , wspace = 0.3)
        plt.imshow(images[r[0]])
        
        plt.title('imagen proyecto : {}'.format(labels[r[0]]))
        plt.xticks([])
        plt.yticks([])
        
    plt.show()
    
display_rand_images(images, labels)

# %% [markdown]
# ## Preparar datos para entrenar el modelo CNN

# %%
""" El paso n.º 1 en la reorganización de datos obtener números igualmente espaciados en un rango dado  """
n = np.arange(images.shape[0])
print("'n' values before shuffling = ",n)

#shuffle todos los valores igualmente espaciados en la lista 'n'
np.random.seed(random_seed)
np.random.shuffle(n)
print("\n'n' values after shuffling = ",n)
# Out:
# 'n' values before shuffling =  [   0    1    2 ... 2726 2727 2728]
#
# 'n' values after shuffling =  [2198 2133  180 ... 2686  348  382]

# %%
"""#2-paso en el barajado de datos
imágenes aleatorias y datos de etiquetas correspondientes en ambas listas"""

images = images[n]
labels = labels[n]

print("Images shape after shuffling = ",images.shape,"\nLabels shape after shuffling = ",labels.shape)
# Out:
# Images shape after shuffling =  (2729,)
# Labels shape after shuffling =  (2729,)

# %%
"""Conversion de las imagenes escalares con matrices de tamaño 1"""
images = images.astype(np.ndarray)
labels = labels.astype(np.int32)
images = images/255
print("Images shape after normalization = ",images.shape)
# Out:
# Images shape after normalization =  (2729,)

# %%
display_rand_images(images, labels)

# %%
""" se define la cantidad de datos tanto oara el entrenamiento como para las pruebas con un valor de 80 y 20"""

train_ds, test_ds, train_labels, test_labels = train_test_split(images, labels, test_size = 0.2, random_state = random_seed)

print("train_ds shape = ",train_ds.shape)
print("train_labels shape = ",train_labels.shape)
print("\ntest_ds shape = ",test_ds.shape)
print("test_labels shape = ",test_labels.shape)
# Out:
# train_ds shape =  (2183,)
# train_labels shape =  (2183,)
#
# test_ds shape =  (546,)
# test_labels shape =  (546,)

# %%
display_rand_images(train_ds, train_labels)

# %% [markdown]
# ##  AlexNet CNN Arquitectura

# %% [markdown]
# Para el reconocimiento de las imagenes se utiliza AlexNet. Resuelve el problema de la clasificación de imágenes con un subconjunto del conjunto de datos de ImageNet, procesar datos de píxeles. Para esta arquitectura usamos 5 capas convolucionales y 3 capas totalmente conectadas.Lo cual especificamos para cada uno de las etiquetas anteriormente detalladas.

# %%
#Programando las capas de la arquitectura AlexNet

# %%
from tensorflow.keras.layers import BatchNormalization
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
#Conv2D = Aplica una convolución 2D sobre una señal de entrada compuesta por varios planos de entrada
#MaxPooling2D = tipo de capa que usa una red convolucional para reconocimiento de imágenes 
#Dense = Las capas Dense son la capas de cálculo de que conectan cada neurona en una capa con todas las salidas de la capa anterior.
#Flatten = La función Flatten agrega argumentos en el orden en que se incluyen en la fórmula.
#Dropout = El dropout se ha utilizado desde su concepción como un método de regularización de los modelos.

#Código que responde a la descripción anterior
#Instanciamos el modelo
model=Sequential()
#Primera capa convolucional
model.add(Conv2D(filters=96,kernel_size=(11,11),strides=(4,4),padding="valid",activation="relu",input_shape=(227,227,3)))
# Primera capa max pool 
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
#Normalizacion batch
model.add(BatchNormalization())
#2 Segunda capa convolucional
model.add(Conv2D(filters=256,kernel_size=(5,5),strides=(1,1),padding="valid",activation="relu"))
#2 Segunda  capa max pool 
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
#Normalizacion batch
model.add(BatchNormalization())
# Tercera capa convolucional
model.add(Conv2D(filters=384,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))
# Cuarta capa convolucional
model.add(Conv2D(filters=384,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))
#Quinta capa convolucional
model.add(Conv2D(filters=256,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))
#Tercers capa max pool 
model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
#Normalizacion pro lote
model.add(BatchNormalization())
#Redimensionar el modelo AlexNet
model.add(Flatten())
#Primera capa de densidad
model.add(Dense(4096,input_shape=(227,227,3),activation="relu"))
#regularizar neuronas
model.add(Dropout(0.4))
#normalizacion por lote
model.add(BatchNormalization())
#Segunda capa de densidad
model.add(Dense(4096,activation="relu"))
#Regularizar neuronas
model.add(Dropout(0.4))
#normalizacion por lotes
model.add(BatchNormalization())
#Tercera capa de densidad
model.add(Dense(1000,activation="relu"))
#regularizar neuronas
model.add(Dropout(0.4))
#normalizacion por lote
model.add(BatchNormalization())
#capa de salida
model.add(Dense(20,activation="softmax"))
#resumen
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 55, 55, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 23, 23, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 384)         885120
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 384)         1327488
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 256)         884992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              4198400
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1000)              4000
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                20020
# =================================================================
# Total params: 28,883,132
# Trainable params: 28,863,532
# Non-trainable params: 19,600
# _________________________________________________________________

# %%
"""Pasarlo a una capa densa"""
model.add(Flatten())


"""# 1ra Capa Densa"""
model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation('relu'))


""" Agreguamos Dropout para evitar el sobreajuste"""
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())


"""2da Capa Densa"""
model.add(Dense(4096))
model.add(Activation('relu'))

""" Agreguamos Dropout para evitar el sobreajuste"""
model.add(Dropout(0.4))
# Batch Normalisation
model.add(BatchNormalization())

"""capa de salida"""
model.add(Dense(1000))

model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 55, 55, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 23, 23, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 384)         885120
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 384)         1327488
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 256)         884992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              4198400
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1000)              4000
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                20020
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              86016
# _________________________________________________________________
# activation (Activation)      (None, 4096)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4096)              16384
# _________________________________________________________________
# dense_6 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# activation_2 (Activation)    (None, 1000)              0
# =================================================================
# Total params: 49,880,228
# Trainable params: 49,844,244
# Non-trainable params: 35,984
# _________________________________________________________________

# %% [markdown]
# SE APLICA EARLY STOP

# %% [markdown]
# Aplicamos la detención temprana que es un método que le permite especificar una gran cantidad arbitraria de épocas de entrenamiento y detener el entrenamiento una vez que el rendimiento del modelo deja de mejorar en un conjunto de datos de validación de espera.

# %%
es= EarlyStopping(monitor='val_loss',mode ='min',verbose=1,patience =200)

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
# %%time 
model.fit(train_ds.values,train_labels, epochs=50,validation_data=(test_ds, test_labels),callbacks=[es]) #Uso del método fit para los valores de entramiento
# Out:
# Accuracy: 86.5134

# %%
loss, accuracy = model.evaluate(test_ds, test_labels) #Perdida y precisión, en la imágen de test y las etquetas de test
print(loss,accuracy) #Mostramos la perdidad y la precisión

# %%
pred = model.predict(test_ds) #Instanciamos la clase model.predict y mandamos por parametro el test
pred.shape #mostramos la prediccion
